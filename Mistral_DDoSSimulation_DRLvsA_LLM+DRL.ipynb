# %% [markdown]
# <a href="https://colab.research.google.com/github/marco-siino/Agentic-ORAN-LLM/blob/main/Mistral_DDoSSimulation_DRLvsA_LLM%2BDRL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Scenario 3 (Semantic Security Override)

# %% [markdown]
# # Installazione librerie

# %%
# !pip install mistralai gymnasium stable-baselines3 shimmy pandas matplotlib
# Out:
# Collecting mistralai
#   Downloading mistralai-2.4.9-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.4/63.4 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.12/dist-packages (1.3.0)
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.8.0-py3-none-any.whl.metadata (4.9 kB)
# Collecting shimmy
#   Downloading shimmy-2.0.1-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Collecting eval-type-backport>=0.2.0 (from mistralai)
#   Downloading eval_type_backport-0.4.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: httpx>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from mistralai) (0.28.1)
# Collecting jsonpath-python>=1.0.6 (from mistralai)
#   Downloading jsonpath_python-1.1.6-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: opentelemetry-api<2.0.0,>=1.33.1 in /usr/local/lib/python3.12/dist-packages (from mistralai) (1.38.0)
# Collecting opentelemetry-semantic-conventions<0.61,>=0.60b1 (from mistralai)
#   Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pydantic>=2.11.2 in /usr/local/lib/python3.12/dist-packages (from mistralai) (2.12.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from mistralai) (2.9.0.post0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mistralai) (0.4.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium) (0.0.6)
# Collecting gymnasium
#   Downloading gymnasium-1.2.3-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.11.0+cpu)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->mistralai) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->mistralai) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->mistralai) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx>=0.28.1->mistralai) (3.18)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx>=0.28.1->mistralai) (0.16.0)
# Requirement already satisfied: importlib-metadata<8.8.0,>=6.0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-api<2.0.0,>=1.33.1->mistralai) (8.7.1)
# Collecting opentelemetry-api<2.0.0,>=1.33.1 (from mistralai)
#   Downloading opentelemetry_api-1.39.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->mistralai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.11.2->mistralai) (2.41.4)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->mistralai) (1.17.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.29.1)
# Requirement already satisfied: setuptools<82 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib-metadata<8.8.0,>=6.0->opentelemetry-api<2.0.0,>=1.33.1->mistralai) (4.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading mistralai-2.4.9-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 8.6 MB/s eta 0:00:00
# Downloading stable_baselines3-2.8.0-py3-none-any.whl (187 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 187.5/187.5 kB 14.3 MB/s eta 0:00:00
# Downloading gymnasium-1.2.3-py3-none-any.whl (952 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 952.1/952.1 kB 26.7 MB/s eta 0:00:00
# Downloading shimmy-2.0.1-py3-none-any.whl (30 kB)
# Downloading eval_type_backport-0.4.0-py3-none-any.whl (6.4 kB)
# Downloading jsonpath_python-1.1.6-py3-none-any.whl (14 kB)
# Downloading opentelemetry_semantic_conventions-0.60b1-py3-none-any.whl (219 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 220.0/220.0 kB 10.9 MB/s eta 0:00:00
# Downloading opentelemetry_api-1.39.1-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.4/66.4 kB 2.7 MB/s eta 0:00:00
# Installing collected packages: jsonpath-python, gymnasium, eval-type-backport, shimmy, opentelemetry-api, stable-baselines3, opentelemetry-semantic-conventions, mistralai
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.3.0
#     Uninstalling gymnasium-1.3.0:
#       Successfully uninstalled gymnasium-1.3.0
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.38.0
#     Uninstalling opentelemetry-api-1.38.0:
#       Successfully uninstalled opentelemetry-api-1.38.0
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.59b0
#     Uninstalling opentelemetry-semantic-conventions-0.59b0:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.59b0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opentelemetry-sdk 1.38.0 requires opentelemetry-api==1.38.0, but you have opentelemetry-api 1.39.1 which is incompatible.
# opentelemetry-sdk 1.38.0 requires opentelemetry-semantic-conventions==0.59b0, but you have opentelemetry-semantic-conventions 0.60b1 which is incompatible.
# google-adk 1.29.0 requires opentelemetry-api<1.39.0,>=1.36.0, but you have opentelemetry-api 1.39.1 which is incompatible.
# Successfully installed eval-type-backport-0.4.0 gymnasium-1.2.3 jsonpath-python-1.1.6 mistralai-2.4.9 opentelemetry-api-1.39.1 opentelemetry-semantic-conventions-0.60b1 shimmy-2.0.1 stable-baselines3-2.8.0

# %% [markdown]
# # Esperimenti finali Paper

# %%
import os
import time
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import gymnasium as gym
from gymnasium import spaces
import requests


# ==============================================================================
# 1. CONFIGURAZIONE
# ==============================================================================
# ⚠️ ATTENZIONE: Questa chiave è esposta. Ti consiglio di revocarla e generarne una nuova.
API_KEY = '7yOu0lH5XcZC1U2ZUI2uv0ghBDduhHp5'
MODEL_NAME = "mistral-small-latest"

USE_MOCK_LLM = False

# ==============================================================================
# 2. LOGICA MISTRAL (API Diretta con Exponential Backoff)
# ==============================================================================
def get_llm_weights_per_cell(step, cell_id, price, traffic, safety_val, external_context):
    prompt_txt = f"""
    Context (Step {step}, Cell {cell_id}):
    - Energy Price: {price:.2f}x
    - Traffic: {traffic:.0f}%
    - External Context: {external_context}

    Task: Output JSON weights (w_thr, w_eng, w_safe) summing to 1.0.
    Logic:
    1. SECURITY QUARANTINE: If DDoS is detected -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).
    2. Emergency (>80): w_safe = 1.0.
    3. Normal: Balance w_thr and w_eng.

    Output JSON ONLY: {{"w_thr": float, "w_eng": float, "w_safe": float}}
    """

    url = "https://api.mistral.ai/v1/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}"
    }
    data = {
        "model": MODEL_NAME,
        "messages": [{"role": "user", "content": prompt_txt}],
        "temperature": 0.1 # Temperatura bassa per JSON più stabili
    }

    max_retries = 5 # Numero massimo di tentativi in caso di Rate Limit

    for attempt in range(max_retries):
        try:
            response = requests.post(url, headers=headers, json=data)

            # Se la chiamata va a buon fine
            if response.status_code == 200:
                result = response.json()
                content = result["choices"][0]["message"]["content"]
                clean_json = content.replace("```json", "").replace("```", "").strip()
                d = json.loads(clean_json)
                return float(d.get('w_thr', 0.3)), float(d.get('w_eng', 0.3)), float(d.get('w_safe', 0.0)), prompt_txt, clean_json

            # Se colpiamo il Rate Limit (429 Too Many Requests)
            elif response.status_code == 429:
                wait_time = 2 ** attempt # Pausa esponenziale: 1s, 2s, 4s, 8s, 16s
                print(f"\n[⚠️ API Limit] Rate limit raggiunto allo step {step}. Attesa di {wait_time}s (Tentativo {attempt+1}/{max_retries})...")
                time.sleep(wait_time)
                continue

            # Per altri errori HTTP (es. 401 Unauthorized, 500 Server Error)
            else:
                print(f"\n[❌ API Error] Step {step}, Cell {cell_id}: HTTP {response.status_code} - {response.text}")
                break # Interrompiamo i tentativi per errori fatali

        except Exception as e:
            print(f"\n[❌ Network Exception] Step {step}, Cell {cell_id}: {e}")
            time.sleep(2) # Pausa fissa prima di riprovare in caso di disconnessione

    # Fallback in caso di fallimento totale
    print(f"\n[!] Fallback attivato per Step {step}, Cell {cell_id}")
    return 0.7, 0.3, 0.0, prompt_txt, '{"error": "failed_after_retries"}'

# ==============================================================================
# 3. AMBIENTE GYM O-RAN (Physics Engine)
# ==============================================================================
class ORAN3CellsEnv(gym.Env):
    def __init__(self):
        super(ORAN3CellsEnv, self).__init__()
        self.n_cells = 3
        self.action_space = spaces.Box(low=5.0, high=60.0, shape=(3,), dtype=np.float32)
        self.observation_space = spaces.Box(low=0, high=100, shape=(10,), dtype=np.float32)

        self.bandwidth = 100.0 # MHz
        self.noise = 1.0       # Noise floor normalizzato
        self.max_pwr = 60.0
        self.min_pwr = 5.0

    def _calculate_metrics(self, power, traffic, price):
        snr = power / self.noise
        capacity = self.bandwidth * np.log2(1 + snr)
        throughput = capacity * (traffic / 100.0)

        consumption = power
        cost = power * price

        risk = ((self.max_pwr - power) / (self.max_pwr - self.min_pwr))**2
        return throughput, consumption, cost, risk

    def step(self, actions, context):
        price = context['price']
        traffic_arr = context['traffic']

        metrics = []
        for i in range(self.n_cells):
            t, cons, c, r = self._calculate_metrics(actions[i], traffic_arr[i], price)
            metrics.append({'thr': t, 'cons': cons, 'cost': c, 'risk': r})

        return np.zeros(10), metrics, False, False, {}

# ==============================================================================
# 4. AGENTE OTTIMIZZATORE (DRL Solver)
# ==============================================================================
def optimize_power(w_thr, w_eng, w_safe, price, traffic, env_instance):
    best_p = 5.0
    best_score = -np.inf

    for p in np.linspace(5, 60, 50):
        t, cons, c, r = env_instance._calculate_metrics(p, traffic, price)

        n_t = t / 800.0
        n_c = c / 600.0
        n_r = r

        score = (w_thr * n_t) - (w_eng * n_c) - (w_safe * n_r)

        if score > best_score:
            best_score = score
            best_p = p

    return best_p

# ==============================================================================
# 5. ESECUZIONE SIMULAZIONE
# ==============================================================================
def run_experiment():
    env = ORAN3CellsEnv()
    steps = 40
    history = []

    # --- GENERAZIONE SCENARI ---
    prices = np.ones(steps)
    prices[15] = 8.0
    for t in range(16, 30):
        prices[t] = 1.0 + 7.0 * np.exp(-0.3 * (t-15))

    traffic_c = []
    np.random.seed(42)
    base_trend = np.linspace(40, 70, steps)
    for i in range(3):
        noise = np.random.normal(0, 5, steps)
        tr = base_trend + noise
        tr = np.clip(tr, 10, 100)
        traffic_c.append(tr)

    safety_c2 = np.zeros(steps)
    safety_c2[25] = 50.0
    safety_c2[26:28] = 100.0
    safety_c2[28] = 50.0

    print("🚀 AVVIO SIMULAZIONE GYM + MISTRAL API...")

    for t in range(steps):
        p = prices[t]
        row_data = {'Step': t, 'Price': p}

        for i in range(3):
            cid = i + 1
            tr = traffic_c[i][t]
            safe = safety_c2[t] if cid == 2 else 0.0

            external_context = "IDS ALERT: DDoS in Cell 3" if (t >= 40 and cid == 3) else "None"

            # --- 1. A-LLM (Agentic) ---
            print(f"\rStep {t}/40 - Cell {cid}: Calling Mistral...", end="", flush=True)

            wa_t, wa_e, wa_s, _, _ = get_llm_weights_per_cell(t, cid, p, tr, safe, external_context)

            # PAUSA DI BASE: Evita di stressare l'API anche se non c'è errore
            time.sleep(1.2)

            p_agentic = optimize_power(wa_t, wa_e, wa_s, p, tr, env)

            # --- 2. DRL (Baseline) ---
            wb_t, wb_e, wb_s = 0.8, 0.2, 0.0
            p_baseline = optimize_power(wb_t, wb_e, wb_s, p, tr, env)

            # --- 3. GYM STEP ---
            ta, cons_a, ca, ra = env._calculate_metrics(p_agentic, tr, p)
            tb, cons_b, cb, rb = env._calculate_metrics(p_baseline, tr, p)

            # Save Data
            prefix = f"C{cid}"
            row_data[f'{prefix}_Traffic'] = tr
            row_data[f'{prefix}_Safety'] = safe

            row_data[f'{prefix}_Cons_A'] = cons_a
            row_data[f'{prefix}_Cons_B'] = cons_b

            row_data[f'{prefix}_Thr_A'] = ta
            row_data[f'{prefix}_Thr_B'] = tb

            row_data[f'{prefix}_Risk_A'] = ra
            row_data[f'{prefix}_Risk_B'] = rb

        history.append(row_data)

    print("\n✅ Simulazione Completata.")
    return pd.DataFrame(history)

# ==============================================================================
# 6. PLOTTING AGGIORNATO
# ==============================================================================
def plot_results(df):
    fig, axes = plt.subplots(3, 3, figsize=(20, 12))
    plt.subplots_adjust(hspace=0.4, wspace=0.35)

    cols = ["Consumo Energetico\n(vs Prezzo)", "Throughput Reale\n(vs Traffico)", "Rischio Sicurezza\n(vs Emergenza)"]
    for ax, t in zip(axes[0], cols): ax.set_title(t, fontweight='bold', pad=15)

    for i in range(3):
        cid = i + 1
        pid = f"C{cid}"

        axes[i, 0].text(-0.25, 0.5, f"CELLA {cid}", transform=axes[i, 0].transAxes,
                        rotation=90, fontweight='bold', fontsize=12, va='center')

        # --- GRAFICO 1 ---
        ax = axes[i, 0]
        l1, = ax.plot(df['Step'], df[f'{pid}_Cons_B'], 'r-', label='DRL (Baseline)')
        l2, = ax.plot(df['Step'], df[f'{pid}_Cons_A'], 'b-', label='A-LLM (Agentic)')
        ax.set_ylim(0, 70)
        ax.set_ylabel("Consumo (W)", fontweight='bold')
        if i==2: ax.set_xlabel("Time Step")

        ax2 = ax.twinx()
        l3, = ax2.plot(df['Step'], df['Price'], 'k--', alpha=0.6, label='Prezzo Energia')
        ax2.fill_between(df['Step'], 0, df['Price'], color='gray', alpha=0.1)
        ax2.set_ylabel("Prezzo ($/kWh)", color='gray')

        if i==0: ax.legend([l1, l2, l3], ['Consumo DRL', 'Consumo A-LLM', 'Prezzo'], loc='upper left', fontsize=8)

        # --- GRAFICO 2 ---
        ax = axes[i, 1]
        l1, = ax.plot(df['Step'], df[f'{pid}_Thr_B'], 'r-')
        l2, = ax.plot(df['Step'], df[f'{pid}_Thr_A'], 'b-')
        ax.set_ylabel("Throughput (Mbps)", fontweight='bold')
        if i==2: ax.set_xlabel("Time Step")

        ax2 = ax.twinx()
        l3, = ax2.plot(df['Step'], df[f'{pid}_Traffic'], 'k--', alpha=0.6)
        ax2.set_ylabel("Utenti (%)", color='gray')
        ax2.set_ylim(0, 110)

        if i==0: ax.legend([l1, l2, l3], ['Thr DRL', 'Thr A-LLM', 'Traffico'], loc='lower right', fontsize=8)

        # --- GRAFICO 3 ---
        ax = axes[i, 2]
        l1, = ax.plot(df['Step'], df[f'{pid}_Risk_B'], 'r-')
        l2, = ax.plot(df['Step'], df[f'{pid}_Risk_A'], 'b-')
        ax.set_ylim(-0.1, 1.1)
        ax.set_ylabel("Rischio (0-1)", fontweight='bold')
        if i==2: ax.set_xlabel("Time Step")

        ax2 = ax.twinx()
        safe_data = df[f'{pid}_Safety']
        l3, = ax2.plot(df['Step'], safe_data, 'k--', alpha=0.6)
        if safe_data.max() > 0:
            ax2.fill_between(df['Step'], 0, safe_data, color='orange', alpha=0.2)
        ax2.set_ylabel("Emergenza (0-100)", color='gray')
        ax2.set_ylim(0, 110)

        if i==0: ax.legend([l1, l2, l3], ['Rischio DRL', 'Rischio A-LLM', 'Emergenza'], loc='upper left', fontsize=8)

    plt.suptitle("SCENARIO 1: Impatto Dinamico (Gym + Mistral API Reale)", fontsize=16, y=0.96)
    plt.savefig("scenario1_gym_mistral.pdf", bbox_inches='tight')
    plt.show()

# ==============================================================================
# ESECUZIONE
# ==============================================================================
if __name__ == "__main__":
    df_results = run_experiment()
    plot_results(df_results)
# Out:
# 🚀 AVVIO SIMULAZIONE GYM + MISTRAL API...
# Step 39/40 - Cell 3: Calling Mistral...
# ✅ Simulazione Completata.

# %%
import os
import time
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
import gymnasium as gym
from gymnasium import spaces
import requests

# ==============================================================================
# 1. CONFIGURAZIONE
# ==============================================================================
API_KEY = '7yOu0lH5XcZC1U2ZUI2uv0ghBDduhHp5' # ⚠️ Ricordati di revocarla/cambiarla in produzione
MODEL_NAME = "mistral-small-latest"

# ==============================================================================
# 2. LOGICA MISTRAL (API Diretta con Exponential Backoff)
# ==============================================================================
def get_llm_weights_per_cell(step, cell_id, price, traffic, safety_val, external_context):
    prompt_txt = f"""
    Context (Step {step}, Cell {cell_id}):
    - Energy Price: {price:.2f}x
    - Traffic: {traffic:.0f}%
    - External Context: {external_context}

    Task: Output JSON weights (w_thr, w_eng, w_safe) summing to 1.0.
    Logic:
    1. SECURITY QUARANTINE: If DDoS is detected -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).
    2. Emergency (>80): w_safe = 1.0.
    3. Normal: Balance w_thr and w_eng.

    Output JSON ONLY: {{"w_thr": float, "w_eng": float, "w_safe": float}}
    """

    url = "https://api.mistral.ai/v1/chat/completions"
    headers = {
        "Content-Type": "application/json",
        "Authorization": f"Bearer {API_KEY}"
    }
    data = {
        "model": MODEL_NAME,
        "messages": [{"role": "user", "content": prompt_txt}],
        "temperature": 0.1
    }

    max_retries = 5
    for attempt in range(max_retries):
        try:
            response = requests.post(url, headers=headers, json=data)

            if response.status_code == 200:
                result = response.json()
                content = result["choices"][0]["message"]["content"]
                clean_json = content.replace("```json", "").replace("```", "").strip()
                d = json.loads(clean_json)
                return float(d.get('w_thr', 0.3)), float(d.get('w_eng', 0.3)), float(d.get('w_safe', 0.0)), prompt_txt, clean_json

            elif response.status_code == 429:
                wait_time = 2 ** attempt
                print(f"\n[⚠️ API Limit] Rate limit raggiunto allo step {step}. Attesa di {wait_time}s (Tentativo {attempt+1}/{max_retries})...")
                time.sleep(wait_time)
                continue
            else:
                print(f"\n[❌ API Error] Step {step}, Cell {cell_id}: HTTP {response.status_code} - {response.text}")
                break

        except Exception as e:
            print(f"\n[❌ Network Exception] Step {step}, Cell {cell_id}: {e}")
            time.sleep(2)

    print(f"\n[!] Fallback attivato per Step {step}, Cell {cell_id}")
    return 0.7, 0.3, 0.0, prompt_txt, '{"error": "failed"}'

# ==============================================================================
# 3. AMBIENTE GYM O-RAN (Physics Engine)
# ==============================================================================
class ORAN3CellsEnv(gym.Env):
    def __init__(self):
        super(ORAN3CellsEnv, self).__init__()
        self.n_cells = 3
        self.action_space = spaces.Box(low=5.0, high=60.0, shape=(3,), dtype=np.float32)
        self.observation_space = spaces.Box(low=0, high=100, shape=(10,), dtype=np.float32)

        self.bandwidth = 100.0
        self.noise = 1.0
        self.max_pwr = 60.0
        self.min_pwr = 5.0

    def _calculate_metrics(self, power, traffic, price):
        snr = power / self.noise
        capacity = self.bandwidth * np.log2(1 + snr)
        throughput = capacity * (traffic / 100.0)

        consumption = power
        cost = power * price

        risk = ((self.max_pwr - power) / (self.max_pwr - self.min_pwr))**2

        # NUOVE METRICHE PER LO SCENARIO C
        sla_compliance = min(100.0, (throughput / 200.0) * 100.0)
        fairness = 1.0 - risk

        return throughput, consumption, cost, risk, sla_compliance, fairness

    def step(self, actions, context):
        pass # Non usato direttamente nel custom loop, usiamo _calculate_metrics

# ==============================================================================
# 4. AGENTE OTTIMIZZATORE (DRL Solver)
# ==============================================================================
def optimize_power(w_thr, w_eng, w_safe, price, traffic, env_instance):
    best_p = 5.0
    best_score = -np.inf

    for p in np.linspace(5, 60, 50):
        # Spacchettamento a 6 variabili
        t, cons, c, r, sla, fair = env_instance._calculate_metrics(p, traffic, price)

        n_t = t / 800.0
        n_c = c / 600.0
        n_r = r

        score = (w_thr * n_t) - (w_eng * n_c) - (w_safe * n_r)

        if score > best_score:
            best_score = score
            best_p = p

    # Ritorna 2 variabili
    return best_p, best_score

# ==============================================================================
# 5. ESECUZIONE SIMULAZIONE (RUN SINGOLA) - SCENARIO C (DDoS)
# ==============================================================================
def run_experiment_single(run_id):
    env = ORAN3CellsEnv()
    steps = 50
    history = []

    np.random.seed(42 + run_id)

    # 1. PREZZO: Shock e decadimento
    prices = np.ones(steps)
    prices[15] = 8.0
    for t in range(16, steps):
        prices[t] = 1.0 + 7.0 * np.exp(-0.3 * (t-15))

    # 2. TRAFFICO E ATTACCO DDOS
    traffic_c = []
    base_trend = np.linspace(40, 70, steps)
    for i in range(3):
        noise = np.random.normal(0, 5, steps)
        tr = np.clip(base_trend + noise, 10, 100)
        traffic_c.append(tr)

    # Inizio attacco DDoS in Cella 3 (Indice 2) dallo step 40
    traffic_c[2][40:steps] = 100.0

    # 3. SAFETY
    safety_c2 = np.zeros(steps)

    print(f"🚀 STARTING SIMULATION RUN {run_id} (SCENARIO C: DDoS)...")

    for t in range(steps):
        p = prices[t]
        row_data = {'Step': t, 'Price': p}

        if t >= 40:
            external_context = "IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3."
        else:
            external_context = "None"

        print(f"\n{'='*80}")
        print(f"⏰ TIMESTEP {t} | Price Factor: {p:.2f}x | Alert: {external_context}")
        print(f"{'='*80}")

        for i in range(3):
            cid = i + 1
            tr = traffic_c[i][t]
            safe = safety_c2[t]

            print(f"\n  📍 CELL {cid} [Load: {tr:.1f}% | Safety: {safe:.0f}]")

            # Pausa preventiva di base per rate limit
            time.sleep(1.2)

            # --- 1. A-LLM (Agentic) ---
            wa_t, wa_e, wa_s, prompt_txt, json_resp = get_llm_weights_per_cell(t, cid, p, tr, safe, external_context)
            p_agentic, duf_agentic = optimize_power(wa_t, wa_e, wa_s, p, tr, env)

            print(f"    🔸 [A-LLM INTERACTION]")
            print(f"       PROMPT TAIL:     ...{json.dumps(prompt_txt.strip()[-150:])}")
            print(f"       OUTPUT JSON:     {json_resp}")
            print(f"       DECIDED WEIGHTS: W_Thr={wa_t:.2f}, W_Eng={wa_e:.2f}, W_Safe={wa_s:.2f}")
            print(f"       CHOSEN POWER:    {p_agentic:.1f} W (DUF: {duf_agentic:.4f})")

            # --- 2. DRL (Baseline) ---
            wb_t, wb_e, wb_s = 0.8, 0.2, 0.0
            p_baseline, duf_baseline = optimize_power(wb_t, wb_e, wb_s, p, tr, env)

            print(f"    🔹 [BASELINE DRL]")
            print(f"       STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00")
            print(f"       CHOSEN POWER:    {p_baseline:.1f} W (DUF: {duf_baseline:.4f})")

            # --- 3. METRICHE FISICHE ---
            ta, cons_a, ca, ra, slaa, faira = env._calculate_metrics(p_agentic, tr, p)
            tb, cons_b, cb, rb, slab, fairb = env._calculate_metrics(p_baseline, tr, p)

            # Salvataggio Dati
            prefix = f"C{cid}"
            row_data[f'{prefix}_Traffic'] = tr
            row_data[f'{prefix}_Safety'] = safe

            # Salvataggio Pesi
            row_data[f'{prefix}_W_Thr_A'] = wa_t
            row_data[f'{prefix}_W_Eng_A'] = wa_e

            row_data[f'{prefix}_Cons_A'] = cons_a
            row_data[f'{prefix}_Cons_B'] = cons_b
            row_data[f'{prefix}_Cost_A'] = ca
            row_data[f'{prefix}_Cost_B'] = cb
            row_data[f'{prefix}_Thr_A'] = ta
            row_data[f'{prefix}_Thr_B'] = tb
            row_data[f'{prefix}_Risk_A'] = ra
            row_data[f'{prefix}_Risk_B'] = rb
            row_data[f'{prefix}_SLA_A'] = slaa
            row_data[f'{prefix}_SLA_B'] = slab
            row_data[f'{prefix}_Fair_A'] = faira
            row_data[f'{prefix}_Fair_B'] = fairb

        history.append(row_data)

    print(f"\n✅ Simulation Run {run_id} Completed.")
    df = pd.DataFrame(history)
    df.to_json(f"results_run_{run_id}.json")
    return df

# ==============================================================================
# 6. PLOTTING SCENARIO C (DDoS)
# ==============================================================================
def plot_results(df):
    fig, axes = plt.subplots(3, 3, figsize=(20, 12))
    plt.subplots_adjust(hspace=0.4, wspace=0.35)

    cols = ["Consumo Energetico\n(vs Prezzo)", "Throughput Reale\n(vs Traffico DDoS)", "SLA Compliance\n(Qualità Servizio)"]
    for ax, t in zip(axes[0], cols): ax.set_title(t, fontweight='bold', pad=15)

    for i in range(3):
        cid = i + 1
        pid = f"C{cid}"

        axes[i, 0].text(-0.25, 0.5, f"CELLA {cid}", transform=axes[i, 0].transAxes,
                        rotation=90, fontweight='bold', fontsize=12, va='center')

        # --- GRAFICO 1: Consumo ---
        ax = axes[i, 0]
        l1, = ax.plot(df['Step'], df[f'{pid}_Cons_B'], 'r-', label='DRL (Baseline)')
        l2, = ax.plot(df['Step'], df[f'{pid}_Cons_A'], 'b-', label='A-LLM (Agentic)')
        # Evidenzia la zona DDoS in grigio
        ax.axvspan(40, 50, color='red', alpha=0.1, lw=0)
        ax.set_ylim(0, 70)
        ax.set_ylabel("Consumo (W)", fontweight='bold')
        if i==2: ax.set_xlabel("Time Step")

        ax2 = ax.twinx()
        l3, = ax2.plot(df['Step'], df['Price'], 'k--', alpha=0.6, label='Prezzo Energia')
        ax2.set_ylabel("Prezzo ($/kWh)", color='gray')

        if i==0: ax.legend([l1, l2, l3], ['Consumo DRL', 'Consumo A-LLM', 'Prezzo'], loc='upper left', fontsize=8)

        # --- GRAFICO 2: Throughput vs Traffico ---
        ax = axes[i, 1]
        l1, = ax.plot(df['Step'], df[f'{pid}_Thr_B'], 'r-')
        l2, = ax.plot(df['Step'], df[f'{pid}_Thr_A'], 'b-')
        ax.axvspan(40, 50, color='red', alpha=0.1, lw=0)
        ax.set_ylabel("Throughput (Mbps)", fontweight='bold')
        if i==2: ax.set_xlabel("Time Step")

        ax2 = ax.twinx()
        l3, = ax2.plot(df['Step'], df[f'{pid}_Traffic'], 'k--', alpha=0.6)
        if cid == 3:
            ax2.fill_between(df['Step'], 0, df[f'{pid}_Traffic'], where=(df['Step']>=40), color='red', alpha=0.2)
        ax2.set_ylabel("Utenti/Traffico (%)", color='gray')
        ax2.set_ylim(0, 110)

        if i==0: ax.legend([l1, l2, l3], ['Thr DRL', 'Thr A-LLM', 'Traffico'], loc='lower left', fontsize=8)

        # --- GRAFICO 3: SLA Compliance ---
        ax = axes[i, 2]
        l1, = ax.plot(df['Step'], df[f'{pid}_SLA_B'], 'r-')
        l2, = ax.plot(df['Step'], df[f'{pid}_SLA_A'], 'b-')
        ax.axvspan(40, 50, color='red', alpha=0.1, lw=0)
        ax.set_ylim(0, 110)
        ax.set_ylabel("SLA Compliance (%)", fontweight='bold')
        if i==2: ax.set_xlabel("Time Step")

        # Pesi A-LLM (Linea verde per W_Eng)
        ax2 = ax.twinx()
        l3, = ax2.plot(df['Step'], df[f'{pid}_W_Eng_A'], 'g:', alpha=0.8)
        ax2.set_ylabel("Peso W_Eng (LLM)", color='green')
        ax2.set_ylim(-0.1, 1.1)

        if i==0: ax.legend([l1, l2, l3], ['SLA DRL', 'SLA A-LLM', 'W_Eng Decision'], loc='lower left', fontsize=8)

    plt.suptitle("SCENARIO C: DDoS Attack & Semantic Response (Gym + Mistral API)", fontsize=16, y=0.96)
    plt.savefig(f"scenarioC_DDoS_Mistral.pdf", bbox_inches='tight')
    plt.show()

# ==============================================================================
# ESECUZIONE MAIN
# ==============================================================================
if __name__ == "__main__":
    RUN_ID = 0
    df_results = run_experiment_single(RUN_ID)
    plot_results(df_results)
# Out:
# 🚀 STARTING SIMULATION RUN 0 (SCENARIO C: DDoS)...
#
# ================================================================================
# ⏰ TIMESTEP 0 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 42.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.42, "w_safe": 0.29}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.42, W_Safe=0.29
#        CHOSEN POWER:    57.8 W (DUF: 0.0496)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2320)
#
#   📍 CELL 2 [Load: 41.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W (DUF: 0.0605)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2268)
#
#   📍 CELL 3 [Load: 32.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.33, "w_eng": 0.67, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.33, W_Eng=0.67, W_Safe=0.00
#        CHOSEN POWER:    16.2 W (DUF: 0.0377)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.1753)
#
# ================================================================================
# ⏰ TIMESTEP 1 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.6, "w_safe": 0.1}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.60, W_Safe=0.10
#        CHOSEN POWER:    51.0 W (DUF: 0.0317)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2168)
#
#   📍 CELL 2 [Load: 38.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.312, "w_eng": 0.608, "w_safe": 0.08}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.61, W_Safe=0.08
#        CHOSEN POWER:    48.8 W (DUF: 0.0323)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2094)
#
#   📍 CELL 3 [Load: 38.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.69, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    17.3 W (DUF: 0.0427)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2084)
#
# ================================================================================
# ⏰ TIMESTEP 2 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W (DUF: 0.0445)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2437)
#
#   📍 CELL 2 [Load: 37.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.61, "w_safe": 0.08}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.61, W_Safe=0.08
#        CHOSEN POWER:    48.8 W (DUF: 0.0297)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2044)
#
#   📍 CELL 3 [Load: 39.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W (DUF: 0.0420)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2143)
#
# ================================================================================
# ⏰ TIMESTEP 3 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 49.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.255, "w_eng": 0.505, "w_safe": 0.24}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.51, W_Safe=0.24
#        CHOSEN POWER:    56.6 W (DUF: 0.0436)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2733)
#
#   📍 CELL 2 [Load: 44.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.275, "w_safe": 0.45}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.28, W_Safe=0.45
#        CHOSEN POWER:    60.0 W (DUF: 0.0640)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2463)
#
#   📍 CELL 3 [Load: 37.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.69, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    17.3 W (DUF: 0.0416)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2043)
#
# ================================================================================
# ⏰ TIMESTEP 4 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.1395)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2248)
#
#   📍 CELL 2 [Load: 47.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.52, "w_eng": 0.48, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.52, W_Eng=0.48, W_Safe=0.00
#        CHOSEN POWER:    54.4 W (DUF: 0.1357)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2623)
#
#   📍 CELL 3 [Load: 41.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W (DUF: 0.0605)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2270)
#
# ================================================================================
# ⏰ TIMESTEP 5 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.71, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.71, W_Safe=0.00
#        CHOSEN POWER:    17.3 W (DUF: 0.0432)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2284)
#
#   📍 CELL 2 [Load: 47.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W (DUF: 0.0383)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2630)
#
#   📍 CELL 3 [Load: 45.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W (DUF: 0.1388)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2474)
#
# ================================================================================
# ⏰ TIMESTEP 6 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 51.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.52, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.52, W_Safe=0.00
#        CHOSEN POWER:    51.0 W (DUF: 0.1322)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2858)
#
#   📍 CELL 2 [Load: 39.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 0.39, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=0.39, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.1395)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2141)
#
#   📍 CELL 3 [Load: 53.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    49.9 W (DUF: 0.1328)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2949)
#
# ================================================================================
# ⏰ TIMESTEP 7 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 48.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W (DUF: 0.0388)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2654)
#
#   📍 CELL 2 [Load: 42.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.1376)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2335)
#
#   📍 CELL 3 [Load: 45.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W (DUF: 0.1391)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2478)
#
# ================================================================================
# ⏰ TIMESTEP 8 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 42.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.1368)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2324)
#
#   📍 CELL 2 [Load: 46.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.265, "w_safe": 0.47}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.27, W_Safe=0.47
#        CHOSEN POWER:    60.0 W (DUF: 0.0650)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2561)
#
#   📍 CELL 3 [Load: 46.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W (DUF: 0.0395)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2539)
#
# ================================================================================
# ⏰ TIMESTEP 9 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 48.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W (DUF: 0.0389)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2660)
#
#   📍 CELL 2 [Load: 50.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.5, "w_eng": 0.5, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.50, W_Eng=0.50, W_Safe=0.00
#        CHOSEN POWER:    53.3 W (DUF: 0.1371)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2788)
#
#   📍 CELL 3 [Load: 45.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.275, "w_safe": 0.45}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.28, W_Safe=0.45
#        CHOSEN POWER:    60.0 W (DUF: 0.0645)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2477)
#
# ================================================================================
# ⏰ TIMESTEP 10 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 43.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.56, "w_eng": 0.44, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.56, W_Eng=0.44, W_Safe=0.00
#        CHOSEN POWER:    58.9 W (DUF: 0.1379)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2398)
#
#   📍 CELL 2 [Load: 43.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.44, "w_safe": 0.28}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.44, W_Safe=0.28
#        CHOSEN POWER:    57.8 W (DUF: 0.0471)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2393)
#
#   📍 CELL 3 [Load: 36.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3145, "w_eng": 0.6155, "w_safe": 0.07}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.62, W_Safe=0.07
#        CHOSEN POWER:    47.7 W (DUF: 0.0281)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.1966)
#
# ================================================================================
# ⏰ TIMESTEP 11 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.44, "w_safe": 0.28}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.44, W_Safe=0.28
#        CHOSEN POWER:    57.8 W (DUF: 0.0485)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2434)
#
#   📍 CELL 2 [Load: 45.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W (DUF: 0.0388)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2517)
#
#   📍 CELL 3 [Load: 46.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.465, "w_safe": 0.27}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.47, W_Safe=0.27
#        CHOSEN POWER:    57.8 W (DUF: 0.0455)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2564)
#
# ================================================================================
# ⏰ TIMESTEP 12 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 48.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.51, "w_eng": 0.49, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.51, W_Eng=0.49, W_Safe=0.00
#        CHOSEN POWER:    53.3 W (DUF: 0.1349)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2680)
#
#   📍 CELL 2 [Load: 41.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W (DUF: 0.0609)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2280)
#
#   📍 CELL 3 [Load: 47.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.52, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.52, W_Safe=0.00
#        CHOSEN POWER:    46.5 W (DUF: 0.1189)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2626)
#
# ================================================================================
# ⏰ TIMESTEP 13 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 38.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.61, "w_safe": 0.08}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.61, W_Safe=0.08
#        CHOSEN POWER:    48.8 W (DUF: 0.0309)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2077)
#
#   📍 CELL 2 [Load: 42.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W (DUF: 0.0612)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2290)
#
#   📍 CELL 3 [Load: 60.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.6, "w_safe": 0.1}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.60, W_Safe=0.10
#        CHOSEN POWER:    54.4 W (DUF: 0.0755)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3375)
#
# ================================================================================
# ⏰ TIMESTEP 14 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W (DUF: 0.0426)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2169)
#
#   📍 CELL 2 [Load: 52.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    49.9 W (DUF: 0.1312)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2922)
#
#   📍 CELL 3 [Load: 47.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.26, "w_eng": 0.52, "w_safe": 0.22}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.52, W_Safe=0.22
#        CHOSEN POWER:    56.6 W (DUF: 0.0406)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2624)
#
# ================================================================================
# ⏰ TIMESTEP 15 | Price Factor: 8.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.54, "w_eng": 0.46, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.54, W_Eng=0.46, W_Safe=0.00
#        CHOSEN POWER:    6.1 W (DUF: 0.0511)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    24.1 W (DUF: 0.1513)
#
#   📍 CELL 2 [Load: 56.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.44, "w_eng": 0.56, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.44, W_Eng=0.56, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: 0.0422)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    29.7 W (DUF: 0.1973)
#
#   📍 CELL 3 [Load: 50.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.49, "w_safe": 0.02}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.49, W_Safe=0.02
#        CHOSEN POWER:    7.2 W (DUF: 0.0288)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    26.3 W (DUF: 0.1717)
#
# ================================================================================
# ⏰ TIMESTEP 16 | Price Factor: 6.19x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    8.4 W (DUF: 0.0604)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    30.8 W (DUF: 0.1597)
#
#   📍 CELL 2 [Load: 49.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.4, "w_eng": 0.6, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.40, W_Eng=0.60, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: 0.0330)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    33.1 W (DUF: 0.1835)
#
#   📍 CELL 3 [Load: 49.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.2, "w_eng": 0.8, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.80, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0092)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    34.2 W (DUF: 0.1844)
#
# ================================================================================
# ⏰ TIMESTEP 17 | Price Factor: 4.84x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 52.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.48, "w_safe": 0.04}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.48, W_Safe=0.04
#        CHOSEN POWER:    16.2 W (DUF: 0.0399)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    45.4 W (DUF: 0.2145)
#
#   📍 CELL 2 [Load: 55.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.45, "w_eng": 0.45, "w_safe": 0.1}
#        DECIDED WEIGHTS: W_Thr=0.45, W_Eng=0.45, W_Safe=0.10
#        CHOSEN POWER:    28.6 W (DUF: 0.0159)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    48.8 W (DUF: 0.2337)
#
#   📍 CELL 3 [Load: 44.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.725, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: 0.0103)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    38.7 W (DUF: 0.1742)
#
# ================================================================================
# ⏰ TIMESTEP 18 | Price Factor: 3.85x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: 0.0172)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    51.0 W (DUF: 0.1996)
#
#   📍 CELL 2 [Load: 52.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.385, "w_safe": 0.145}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.39, W_Safe=0.14
#        CHOSEN POWER:    44.3 W (DUF: 0.0496)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    58.9 W (DUF: 0.2364)
#
#   📍 CELL 3 [Load: 56.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.215, "w_eng": 0.785, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.21, W_Eng=0.79, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: 0.0143)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2596)
#
# ================================================================================
# ⏰ TIMESTEP 19 | Price Factor: 3.11x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    18.5 W (DUF: 0.0882)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2022)
#
#   📍 CELL 2 [Load: 48.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.26, "w_eng": 0.74, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.74, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: 0.0215)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2249)
#
#   📍 CELL 3 [Load: 55.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.45, "w_eng": 0.55, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.45, W_Eng=0.55, W_Safe=0.00
#        CHOSEN POWER:    15.1 W (DUF: 0.0819)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2664)
#
# ================================================================================
# ⏰ TIMESTEP 20 | Price Factor: 2.56x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 59.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.2, "w_eng": 0.8, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.80, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: 0.0214)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3021)
#
#   📍 CELL 2 [Load: 54.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.77, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.77, W_Safe=0.00
#        CHOSEN POWER:    6.1 W (DUF: 0.0239)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2693)
#
#   📍 CELL 3 [Load: 56.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.22, "w_eng": 0.78, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.22, W_Eng=0.78, W_Safe=0.00
#        CHOSEN POWER:    6.1 W (DUF: 0.0234)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2821)
#
# ================================================================================
# ⏰ TIMESTEP 21 | Price Factor: 2.16x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 51.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    7.2 W (DUF: 0.0274)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2636)
#
#   📍 CELL 2 [Load: 60.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.195, "w_eng": 0.205, "w_safe": 0.6}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.20, W_Safe=0.60
#        CHOSEN POWER:    58.9 W (DUF: 0.0435)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3159)
#
#   📍 CELL 3 [Load: 48.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.26, "w_eng": 0.74, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.74, W_Safe=0.00
#        CHOSEN POWER:    7.2 W (DUF: 0.0285)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2434)
#
# ================================================================================
# ⏰ TIMESTEP 22 | Price Factor: 1.86x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 53.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.77, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.77, W_Safe=0.00
#        CHOSEN POWER:    8.4 W (DUF: 0.0300)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2820)
#
#   📍 CELL 2 [Load: 53.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.235, "w_eng": 0.925, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.93, W_Safe=0.00
#        CHOSEN POWER:    7.2 W (DUF: 0.0269)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2789)
#
#   📍 CELL 3 [Load: 60.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.2, "w_eng": 0.8, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.80, W_Safe=0.00
#        CHOSEN POWER:    8.4 W (DUF: 0.0281)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3216)
#
# ================================================================================
# ⏰ TIMESTEP 23 | Price Factor: 1.64x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 47.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.2, "w_eng": 0.8, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.80, W_Safe=0.00
#        CHOSEN POWER:    7.2 W (DUF: 0.0199)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2458)
#
#   📍 CELL 2 [Load: 61.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.19, "w_eng": 1.64, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.19, W_Eng=1.64, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: 0.0157)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3344)
#
#   📍 CELL 3 [Load: 47.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.735, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    10.6 W (DUF: 0.0339)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2465)
#
# ================================================================================
# ⏰ TIMESTEP 24 | Price Factor: 1.47x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 52.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.73, "w_safe": 0.03}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.73, W_Safe=0.03
#        CHOSEN POWER:    20.7 W (DUF: 0.0169)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2788)
#
#   📍 CELL 2 [Load: 41.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.58, "w_safe": 0.13}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.58, W_Safe=0.13
#        CHOSEN POWER:    48.8 W (DUF: 0.0103)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.2173)
#
#   📍 CELL 3 [Load: 57.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.78, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.78, W_Safe=0.00
#        CHOSEN POWER:    15.1 W (DUF: 0.0549)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3124)
#
# ================================================================================
# ⏰ TIMESTEP 25 | Price Factor: 1.35x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 55.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.22, "w_eng": 0.78, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.22, W_Eng=0.78, W_Safe=0.00
#        CHOSEN POWER:    11.7 W (DUF: 0.0358)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3043)
#
#   📍 CELL 2 [Load: 59.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
# ...
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0084)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.5730)
#
# ================================================================================
# ⏰ TIMESTEP 42 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 65.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0084)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3663)
#
#   📍 CELL 2 [Load: 62.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0084)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3489)
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0084)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.5730)
#
# ================================================================================
# ⏰ TIMESTEP 43 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 64.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3644)
#
#   📍 CELL 2 [Load: 64.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3636)
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.5730)
#
# ================================================================================
# ⏰ TIMESTEP 44 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 59.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3331)
#
#   📍 CELL 2 [Load: 65.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3653)
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.5731)
#
# ================================================================================
# ⏰ TIMESTEP 45 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 64.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3593)
#
#   📍 CELL 2 [Load: 60.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3372)
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.5731)
#
# ================================================================================
# ⏰ TIMESTEP 46 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 65.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3706)
#
#   📍 CELL 2 [Load: 69.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3930)
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.5731)
#
# ================================================================================
# ⏰ TIMESTEP 47 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 74.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.4192)
#
#   📍 CELL 2 [Load: 70.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3956)
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.5731)
#
# ================================================================================
# ⏰ TIMESTEP 48 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 71.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.4017)
#
#   📍 CELL 2 [Load: 69.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3917)
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.5731)
#
# ================================================================================
# ⏰ TIMESTEP 49 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 61.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3429)
#
#   📍 CELL 2 [Load: 68.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.3882)
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W (DUF: -0.0083)
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W (DUF: 0.5731)
#
# ✅ Simulation Run 0 Completed.

# %%
# ==============================================================================
# CELLA 4: GENERAZIONE GRAFICI E PDF (IEEE STYLE) - SCENARIO C (DDoS)
# ==============================================================================
import pandas as pd
import matplotlib.pyplot as plt

def generate_plots(run_id_to_plot=0):
    # Carica i dati della run
    filename = f"results_run_{run_id_to_plot}.json"
    try:
        df = pd.read_json(filename)
        print(f"📊 Loading data from {filename} for plotting...")
    except:
        print(f"❌ Error: Could not find {filename}. Make sure to run the simulation first.")
        return

    # Setup parametri grafici per IEEE Papers
    plt.rcParams.update({
        'font.size': 10,
        'font.family': 'serif',
        'axes.labelsize': 10,
        'axes.titlesize': 11,
        'xtick.labelsize': 9,
        'ytick.labelsize': 9,
        'legend.fontsize': 9,
        'lines.linewidth': 1.5,
        'figure.titlesize': 13
    })

    # Creazione Figura 3x3
    fig, axes = plt.subplots(3, 3, figsize=(18, 12))
    plt.subplots_adjust(hspace=0.4, wspace=0.35)

    # Titoli delle Colonne per lo Scenario DDoS
    cols = ["Power Consumption\n(vs. Energy Price)",
            "Achieved Throughput\n(vs. Traffic Load)",
            "SLA Compliance\n(vs. LLM Policy Shift)"]

    for ax, t in zip(axes[0], cols):
        ax.set_title(t, fontweight='bold', pad=15)

    # Iterazione sulle 3 Celle (Righe)
    for i in range(3):
        cid = i + 1
        pid = f"C{cid}"

        # Etichetta laterale
        axes[i, 0].text(-0.35, 0.5, f"CELL {cid}", transform=axes[i, 0].transAxes,
                        rotation=90, fontweight='bold', fontsize=12, va='center')

        # --- COLONNA 1: Power (Sx) vs Price (Dx) ---
        ax = axes[i, 0]
        l1, = ax.plot(df['Step'], df[f'{pid}_Cons_B'], 'r-', label='Baseline (DRL)')
        l2, = ax.plot(df['Step'], df[f'{pid}_Cons_A'], 'b-', linewidth=2.0, label='Proposed (A-LLM)')

        # Evidenzia la finestra del DDoS (Step 40-50)
        ax.axvspan(40, 50, color='red', alpha=0.08, lw=0)

        ax.set_ylim(0, 70)
        ax.set_ylabel("Power Consumption (W)", fontweight='bold')
        ax.grid(True, linestyle=':', alpha=0.6)
        if i==2: ax.set_xlabel("Time Step")

        ax2 = ax.twinx()
        l3, = ax2.plot(df['Step'], df['Price'], 'k--', alpha=0.6, label='Energy Price')
        ax2.fill_between(df['Step'], 0, df['Price'], color='gray', alpha=0.1)
        ax2.set_ylabel("Energy Price (x)", color='gray', fontsize=9)

        if i==0:
            lines = [l1, l2, l3]
            labels = [l.get_label() for l in lines]
            ax.legend(lines, labels, loc='upper left', frameon=True, fancybox=True, framealpha=0.9)

        # --- COLONNA 2: Throughput (Sx) vs Traffic (Dx) ---
        ax = axes[i, 1]
        l1, = ax.plot(df['Step'], df[f'{pid}_Thr_B'], 'r-', label='Baseline (DRL)')
        l2, = ax.plot(df['Step'], df[f'{pid}_Thr_A'], 'b-', linewidth=2.0, label='Proposed (A-LLM)')
        ax.axvspan(40, 50, color='red', alpha=0.08, lw=0)

        ax.set_ylabel("Throughput (Mbps)", fontweight='bold')
        ax.grid(True, linestyle=':', alpha=0.6)
        if i==2: ax.set_xlabel("Time Step")

        ax2 = ax.twinx()
        l3, = ax2.plot(df['Step'], df[f'{pid}_Traffic'], 'm--', alpha=0.6, label='Traffic Load')
        # Colora di rosso il traffico anomalo nella Cella 3
        if cid == 3:
            ax2.fill_between(df['Step'], 0, df[f'{pid}_Traffic'], where=(df['Step']>=40), color='red', alpha=0.2)

        ax2.set_ylabel("Traffic Load (%)", color='magenta', fontsize=9)
        ax2.set_ylim(0, 110)

        if i==0:
            ax.legend([l1, l2, l3], ['Baseline', 'A-LLM', 'Traffic'], loc='lower left', frameon=True)

        # --- COLONNA 3: SLA Compliance (Sx) vs LLM Weight Shift (Dx) ---
        ax = axes[i, 2]
        l1, = ax.plot(df['Step'], df[f'{pid}_SLA_B'], 'r-', label='Baseline (DRL)')
        l2, = ax.plot(df['Step'], df[f'{pid}_SLA_A'], 'b-', linewidth=2.0, label='Proposed (A-LLM)')
        ax.axvspan(40, 50, color='red', alpha=0.08, lw=0)

        ax.set_ylim(0, 110)
        ax.set_ylabel("SLA Compliance (%)", fontweight='bold')
        ax.grid(True, linestyle=':', alpha=0.6)
        if i==2: ax.set_xlabel("Time Step")

        # Asse secondario: mostriamo la decisione semantica dell'LLM (Peso Energia/Quarantena)
        ax2 = ax.twinx()
        l3, = ax2.plot(df['Step'], df[f'{pid}_W_Eng_A'], 'g-.', linewidth=2.0, alpha=0.8, label='LLM Policy: w_eng')
        ax2.set_ylabel("LLM Energy Weight (w_eng)", color='green', fontsize=9)
        ax2.set_ylim(-0.1, 1.1)

        if i==0:
            ax.legend([l1, l2, l3], ['Baseline SLA', 'A-LLM SLA', 'LLM Policy'], loc='center left', frameon=True)

    # Titolo Globale Aggiornato
    plt.suptitle("Scenario C: Autonomous System Response to Localized DDoS Attack (Semantic Quarantine)",
                 fontsize=14, y=0.96)

    # Salvataggio PDF
    pdf_filename = "scenarioC_ieee_tccn_ddos_results.pdf"
    plt.savefig(pdf_filename, bbox_inches='tight', dpi=300)
    print(f"✅ Plot generated and saved to: {pdf_filename}")
    plt.show()

# Esegui la funzione
if __name__ == "__main__":
    generate_plots(run_id_to_plot=0)
# Out:
# 📊 Loading data from results_run_0.json for plotting...
# ✅ Plot generated and saved to: scenarioC_ieee_tccn_ddos_results.pdf

# %% [markdown]
# ## Run 0

# %%
# ==============================================================================
# 5. ESECUZIONE SIMULAZIONE (RUN SINGOLA) - SCENARIO 3 (DDoS)
# ==============================================================================

# --- CAMBIA QUESTO ID IN OGNI CELLA (0, 1, 2, 3, 4) ---
RUN_ID = 0
# ------------------------------------------------------

def run_experiment_single(run_id):
    env = ORAN3CellsEnv()
    steps = 50 # <-- Aumentato a 50 per mostrare il DDoS
    history = []

    # --- Generazione Scenari (SEED DIVERSO) ---
    np.random.seed(42 + run_id) # <--- Seed Variabile

    # 1. PREZZO
    prices = np.ones(steps)
    prices[15] = 8.0
    for t in range(16, steps): # <-- Arriva fino alla fine (50)
        prices[t] = 1.0 + 7.0 * np.exp(-0.3 * (t-15))

    # 2. TRAFFICO
    traffic_c = []
    base_trend = np.linspace(40, 70, steps)
    for i in range(3):
        noise = np.random.normal(0, 5, steps)
        tr = np.clip(base_trend + noise, 10, 100)
        traffic_c.append(tr)

    # --- INIZIO ATTACCO DDoS IN CELLA 3 (Indice 2) ---
    traffic_c[2][40:steps] = 100.0

    # 3. SAFETY (Disattivata in questo scenario)
    safety_c2 = np.zeros(steps)

    print(f"🚀 STARTING SIMULATION RUN {run_id} (SCENARIO 3: DDoS)...")

    for t in range(steps):
        p = prices[t]
        row_data = {'Step': t, 'Price': p}

        # --- CONTESTO ESTERNO (ALLERTA DDoS) ---
        if t >= 40:
            external_context = "IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3."
        else:
            external_context = "None"

        print(f"\n{'='*80}")
        print(f"⏰ TIMESTEP {t} | Price Factor: {p:.2f}x | Alert: {external_context}")
        print(f"{'='*80}")

        # Iteriamo sulle 3 Celle
        for i in range(3):
            cid = i + 1
            tr = traffic_c[i][t]
            safe = safety_c2[t]

            print(f"\n  📍 CELL {cid} [Load: {tr:.1f}% | Safety: {safe:.0f}]")

            # AGGIUNTO SLEEP PREVENTIVO (Mantenuto a 1.2s per stabilità API Mistral)
            time.sleep(1.2)

            # --- 1. A-LLM (Agentic) ---
            # AGGIUNTO IL SESTO PARAMETRO: external_context
            wa_t, wa_e, wa_s, prompt_txt, json_resp = get_llm_weights_per_cell(t, cid, p, tr, safe, external_context)
            p_agentic, duf_agentic = optimize_power(wa_t, wa_e, wa_s, p, tr, env)

            # LOG TRASPARENZA A-LLM
            print(f"    🔸 [A-LLM INTERACTION]")
            print(f"       PROMPT TAIL:     ...{json.dumps(prompt_txt.strip()[-200:])}")
            print(f"       OUTPUT JSON:     {json_resp}")
            print(f"       DECIDED WEIGHTS: W_Thr={wa_t:.2f}, W_Eng={wa_e:.2f}, W_Safe={wa_s:.2f}")
            print(f"       CHOSEN POWER:    {p_agentic:.1f} W")
            print(f"       DUF SCORE:       {duf_agentic:.4f}")

            # --- 2. DRL (Baseline) ---
            wb_t, wb_e, wb_s = 0.8, 0.2, 0.0
            p_baseline, duf_baseline = optimize_power(wb_t, wb_e, wb_s, p, tr, env)

            # LOG TRASPARENZA BASELINE
            print(f"    🔹 [BASELINE DRL]")
            print(f"       STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00")
            print(f"       CHOSEN POWER:    {p_baseline:.1f} W")
            print(f"       DUF SCORE:       {duf_baseline:.4f}")

            # --- 3. METRICHE FISICHE ---
            ta, cons_a, ca, ra, slaa, faira = env._calculate_metrics(p_agentic, tr, p)
            tb, cons_b, cb, rb, slab, fairb = env._calculate_metrics(p_baseline, tr, p)

            # Save Data
            prefix = f"C{cid}"
            row_data[f'{prefix}_Traffic'] = tr
            row_data[f'{prefix}_Safety'] = safe

            # Salviamo i pesi per il plot
            row_data[f'{prefix}_W_Thr_A'] = wa_t
            row_data[f'{prefix}_W_Eng_A'] = wa_e
            row_data[f'{prefix}_W_Safe_A'] = wa_s

            row_data[f'{prefix}_Cons_A'] = cons_a
            row_data[f'{prefix}_Cons_B'] = cons_b
            row_data[f'{prefix}_Cost_A'] = ca
            row_data[f'{prefix}_Cost_B'] = cb
            row_data[f'{prefix}_Thr_A'] = ta
            row_data[f'{prefix}_Thr_B'] = tb
            row_data[f'{prefix}_Risk_A'] = ra
            row_data[f'{prefix}_Risk_B'] = rb

            # Save Advanced Metrics
            row_data[f'{prefix}_SLA_A'] = slaa
            row_data[f'{prefix}_Fair_A'] = faira
            row_data[f'{prefix}_SLA_B'] = slab
            row_data[f'{prefix}_Fair_B'] = fairb

        history.append(row_data)

    print(f"\n✅ Simulation Run {run_id} Completed.")

    # SALVATAGGIO FONDAMENTALE PER LA TABELLA
    df = pd.DataFrame(history)
    df.to_json(f"results_scenario3_run_{run_id}.json")
    return df

# ESECUZIONE
df_res = run_experiment_single(RUN_ID)
# Out:
# 🚀 STARTING SIMULATION RUN 0 (SCENARIO 3: DDoS)...
#
# ================================================================================
# ⏰ TIMESTEP 0 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 42.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.42, "w_safe": 0.29}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.42, W_Safe=0.29
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.0496
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2320
#
#   📍 CELL 2 [Load: 41.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0605
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2268
#
#   📍 CELL 3 [Load: 32.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.33, "w_eng": 0.67, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.33, W_Eng=0.67, W_Safe=0.00
#        CHOSEN POWER:    16.2 W
#        DUF SCORE:       0.0377
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1753
#
# ================================================================================
# ⏰ TIMESTEP 1 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.6, "w_safe": 0.1}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.60, W_Safe=0.10
#        CHOSEN POWER:    51.0 W
#        DUF SCORE:       0.0317
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2168
#
#   📍 CELL 2 [Load: 38.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.312, "w_eng": 0.608, "w_safe": 0.08}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.61, W_Safe=0.08
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       0.0323
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2094
#
#   📍 CELL 3 [Load: 38.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.39, "w_eng": 0.61, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.39, W_Eng=0.61, W_Safe=0.00
#        CHOSEN POWER:    25.2 W
#        DUF SCORE:       0.0628
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2084
#
# ================================================================================
# ⏰ TIMESTEP 2 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0445
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2437
#
#   📍 CELL 2 [Load: 37.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.61, "w_safe": 0.08}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.61, W_Safe=0.08
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       0.0297
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2044
#
#   📍 CELL 3 [Load: 39.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0420
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2143
#
# ================================================================================
# ⏰ TIMESTEP 3 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 49.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1293
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2733
#
#   📍 CELL 2 [Load: 44.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1381
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2463
#
#   📍 CELL 3 [Load: 37.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.69, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0416
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2043
#
# ================================================================================
# ⏰ TIMESTEP 4 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1395
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2248
#
#   📍 CELL 2 [Load: 47.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.52, "w_eng": 0.48, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.52, W_Eng=0.48, W_Safe=0.00
#        CHOSEN POWER:    54.4 W
#        DUF SCORE:       0.1357
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2623
#
#   📍 CELL 3 [Load: 41.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0605
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2270
#
# ================================================================================
# ⏰ TIMESTEP 5 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.58, "w_safe": 0.13}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.58, W_Safe=0.13
#        CHOSEN POWER:    53.3 W
#        DUF SCORE:       0.0341
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2284
#
#   📍 CELL 2 [Load: 47.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0383
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2630
#
#   📍 CELL 3 [Load: 45.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1388
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2474
#
# ================================================================================
# ⏰ TIMESTEP 6 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 51.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.52, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.52, W_Safe=0.00
#        CHOSEN POWER:    51.0 W
#        DUF SCORE:       0.1322
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2858
#
#   📍 CELL 2 [Load: 39.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 0.39, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=0.39, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1395
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2141
#
#   📍 CELL 3 [Load: 53.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1328
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2949
#
# ================================================================================
# ⏰ TIMESTEP 7 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 48.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0388
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2654
#
#   📍 CELL 2 [Load: 42.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1376
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2335
#
#   📍 CELL 3 [Load: 45.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1391
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2478
#
# ================================================================================
# ⏰ TIMESTEP 8 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 42.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1368
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2324
#
#   📍 CELL 2 [Load: 46.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.1360
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2561
#
#   📍 CELL 3 [Load: 46.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0395
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2539
#
# ================================================================================
# ⏰ TIMESTEP 9 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 48.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.52, "w_eng": 0.48, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.52, W_Eng=0.48, W_Safe=0.00
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.1380
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2660
#
#   📍 CELL 2 [Load: 50.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.5, "w_eng": 0.5, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.50, W_Eng=0.50, W_Safe=0.00
#        CHOSEN POWER:    53.3 W
#        DUF SCORE:       0.1371
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2788
#
#   📍 CELL 3 [Load: 45.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1391
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2477
#
# ================================================================================
# ⏰ TIMESTEP 10 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 43.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.56, "w_eng": 0.44, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.56, W_Eng=0.44, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1379
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2398
#
#   📍 CELL 2 [Load: 43.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.44, "w_safe": 0.28}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.44, W_Safe=0.28
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.0471
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2393
#
#   📍 CELL 3 [Load: 36.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3145, "w_eng": 0.6155, "w_safe": 0.07}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.62, W_Safe=0.07
#        CHOSEN POWER:    47.7 W
#        DUF SCORE:       0.0281
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1966
#
# ================================================================================
# ⏰ TIMESTEP 11 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.44, "w_safe": 0.28}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.44, W_Safe=0.28
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.0485
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2434
#
#   📍 CELL 2 [Load: 45.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0388
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2517
#
#   📍 CELL 3 [Load: 46.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.265, "w_safe": 0.47}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.27, W_Safe=0.47
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0651
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2564
#
# ================================================================================
# ⏰ TIMESTEP 12 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 48.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.51, "w_eng": 0.49, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.51, W_Eng=0.49, W_Safe=0.00
#        CHOSEN POWER:    53.3 W
#        DUF SCORE:       0.1349
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2680
#
#   📍 CELL 2 [Load: 41.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0609
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2280
#
#   📍 CELL 3 [Load: 47.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.52, "w_eng": 0.48, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.52, W_Eng=0.48, W_Safe=0.00
#        CHOSEN POWER:    54.4 W
#        DUF SCORE:       0.1359
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2626
#
# ================================================================================
# ⏰ TIMESTEP 13 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 38.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.69, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0425
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2077
#
#   📍 CELL 2 [Load: 42.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0612
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2290
#
#   📍 CELL 3 [Load: 60.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.6, "w_safe": 0.1}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.60, W_Safe=0.10
#        CHOSEN POWER:    54.4 W
#        DUF SCORE:       0.0755
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3375
#
# ================================================================================
# ⏰ TIMESTEP 14 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0426
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2169
#
#   📍 CELL 2 [Load: 52.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1312
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2922
#
#   📍 CELL 3 [Load: 47.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.26, "w_eng": 0.52, "w_safe": 0.22}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.52, W_Safe=0.22
#        CHOSEN POWER:    56.6 W
#        DUF SCORE:       0.0406
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2624
#
# ================================================================================
# ⏰ TIMESTEP 15 | Price Factor: 8.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.54, "w_eng": 0.46, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.54, W_Eng=0.46, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0511
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    24.1 W
#        DUF SCORE:       0.1513
#
#   📍 CELL 2 [Load: 56.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.44, "w_eng": 0.56, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.44, W_Eng=0.56, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0422
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    29.7 W
#        DUF SCORE:       0.1973
#
#   📍 CELL 3 [Load: 50.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 0.0, "w_safe": 1.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=0.00, W_Safe=1.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0000
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    26.3 W
#        DUF SCORE:       0.1717
#
# ================================================================================
# ⏰ TIMESTEP 16 | Price Factor: 6.19x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.45, "w_eng": 0.55, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.45, W_Eng=0.55, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0367
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    30.8 W
#        DUF SCORE:       0.1597
#
#   📍 CELL 2 [Load: 49.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.4, "w_eng": 0.6, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.40, W_Eng=0.60, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0330
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    33.1 W
#        DUF SCORE:       0.1835
#
#   📍 CELL 3 [Load: 49.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0014
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    34.2 W
#        DUF SCORE:       0.1844
#
# ================================================================================
# ⏰ TIMESTEP 17 | Price Factor: 4.84x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 52.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.48, "w_safe": 0.04}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.48, W_Safe=0.04
#        CHOSEN POWER:    16.2 W
#        DUF SCORE:       0.0399
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    45.4 W
#        DUF SCORE:       0.2145
#
#   📍 CELL 2 [Load: 55.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.45, "w_eng": 0.45, "w_safe": 0.1}
#        DECIDED WEIGHTS: W_Thr=0.45, W_Eng=0.45, W_Safe=0.10
#        CHOSEN POWER:    28.6 W
#        DUF SCORE:       0.0159
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       0.2337
#
#   📍 CELL 3 [Load: 44.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.725, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0103
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    38.7 W
#        DUF SCORE:       0.1742
#
# ================================================================================
# ⏰ TIMESTEP 18 | Price Factor: 3.85x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0172
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    51.0 W
#        DUF SCORE:       0.1996
#
#   📍 CELL 2 [Load: 52.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.385, "w_safe": 0.145}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.39, W_Safe=0.14
#        CHOSEN POWER:    44.3 W
#        DUF SCORE:       0.0496
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.2364
#
#   📍 CELL 3 [Load: 56.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.215, "w_eng": 0.785, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.21, W_Eng=0.79, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0143
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2596
#
# ================================================================================
# ⏰ TIMESTEP 19 | Price Factor: 3.11x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    18.5 W
#        DUF SCORE:       0.0882
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2022
#
#   📍 CELL 2 [Load: 48.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.26, "w_eng": 0.74, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.74, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0215
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2249
#
#   📍 CELL 3 [Load: 55.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.45, "w_eng": 0.55, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.45, W_Eng=0.55, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0819
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2664
#
# ================================================================================
# ⏰ TIMESTEP 20 | Price Factor: 2.56x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 59.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.2, "w_eng": 0.8, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.80, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0214
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3021
#
#   📍 CELL 2 [Load: 54.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.77, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.77, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0239
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2693
#
#   📍 CELL 3 [Load: 56.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.22, "w_eng": 0.78, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.22, W_Eng=0.78, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0234
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2821
#
# ================================================================================
# ⏰ TIMESTEP 21 | Price Factor: 2.16x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 51.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0274
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2636
#
#   📍 CELL 2 [Load: 60.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.195, "w_eng": 0.805, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.81, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0241
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3159
#
#   📍 CELL 3 [Load: 48.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.26, "w_eng": 0.74, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.74, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0285
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2434
#
# ================================================================================
# ⏰ TIMESTEP 22 | Price Factor: 1.86x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 53.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.77, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.77, W_Safe=0.00
#        CHOSEN POWER:    8.4 W
#        DUF SCORE:       0.0300
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2820
#
#   📍 CELL 2 [Load: 53.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
# ...
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0084
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 43 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 64.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3644
#
#   📍 CELL 2 [Load: 64.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3636
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 44 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 59.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3331
#
#   📍 CELL 2 [Load: 65.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3653
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 45 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 64.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3593
#
#   📍 CELL 2 [Load: 60.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3372
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 46 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 65.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3706
#
#   📍 CELL 2 [Load: 69.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3930
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 47 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 74.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4192
#
#   📍 CELL 2 [Load: 70.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3956
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 48 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 71.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4017
#
#   📍 CELL 2 [Load: 69.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3917
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 49 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 61.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3429
#
#   📍 CELL 2 [Load: 68.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3882
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ✅ Simulation Run 0 Completed.

# %% [markdown]
# ## Run 1

# %%
# ==============================================================================
# 5. ESECUZIONE SIMULAZIONE (RUN SINGOLA) - SCENARIO 3 (DDoS)
# ==============================================================================

# --- CAMBIA QUESTO ID IN OGNI CELLA (0, 1, 2, 3, 4) ---
RUN_ID = 1
# ------------------------------------------------------

def run_experiment_single(run_id):
    env = ORAN3CellsEnv()
    steps = 50 # <-- Aumentato a 50 per mostrare il DDoS
    history = []

    # --- Generazione Scenari (SEED DIVERSO) ---
    np.random.seed(42 + run_id) # <--- Seed Variabile

    # 1. PREZZO
    prices = np.ones(steps)
    prices[15] = 8.0
    for t in range(16, steps): # <-- Arriva fino alla fine (50)
        prices[t] = 1.0 + 7.0 * np.exp(-0.3 * (t-15))

    # 2. TRAFFICO
    traffic_c = []
    base_trend = np.linspace(40, 70, steps)
    for i in range(3):
        noise = np.random.normal(0, 5, steps)
        tr = np.clip(base_trend + noise, 10, 100)
        traffic_c.append(tr)

    # --- INIZIO ATTACCO DDoS IN CELLA 3 (Indice 2) ---
    traffic_c[2][40:steps] = 100.0

    # 3. SAFETY (Disattivata in questo scenario)
    safety_c2 = np.zeros(steps)

    print(f"🚀 STARTING SIMULATION RUN {run_id} (SCENARIO 3: DDoS)...")

    for t in range(steps):
        p = prices[t]
        row_data = {'Step': t, 'Price': p}

        # --- CONTESTO ESTERNO (ALLERTA DDoS) ---
        if t >= 40:
            external_context = "IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3."
        else:
            external_context = "None"

        print(f"\n{'='*80}")
        print(f"⏰ TIMESTEP {t} | Price Factor: {p:.2f}x | Alert: {external_context}")
        print(f"{'='*80}")

        # Iteriamo sulle 3 Celle
        for i in range(3):
            cid = i + 1
            tr = traffic_c[i][t]
            safe = safety_c2[t]

            print(f"\n  📍 CELL {cid} [Load: {tr:.1f}% | Safety: {safe:.0f}]")

            # AGGIUNTO SLEEP PREVENTIVO (Mantenuto a 1.2s per stabilità API Mistral)
            time.sleep(1.2)

            # --- 1. A-LLM (Agentic) ---
            # AGGIUNTO IL SESTO PARAMETRO: external_context
            wa_t, wa_e, wa_s, prompt_txt, json_resp = get_llm_weights_per_cell(t, cid, p, tr, safe, external_context)
            p_agentic, duf_agentic = optimize_power(wa_t, wa_e, wa_s, p, tr, env)

            # LOG TRASPARENZA A-LLM
            print(f"    🔸 [A-LLM INTERACTION]")
            print(f"       PROMPT TAIL:     ...{json.dumps(prompt_txt.strip()[-200:])}")
            print(f"       OUTPUT JSON:     {json_resp}")
            print(f"       DECIDED WEIGHTS: W_Thr={wa_t:.2f}, W_Eng={wa_e:.2f}, W_Safe={wa_s:.2f}")
            print(f"       CHOSEN POWER:    {p_agentic:.1f} W")
            print(f"       DUF SCORE:       {duf_agentic:.4f}")

            # --- 2. DRL (Baseline) ---
            wb_t, wb_e, wb_s = 0.8, 0.2, 0.0
            p_baseline, duf_baseline = optimize_power(wb_t, wb_e, wb_s, p, tr, env)

            # LOG TRASPARENZA BASELINE
            print(f"    🔹 [BASELINE DRL]")
            print(f"       STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00")
            print(f"       CHOSEN POWER:    {p_baseline:.1f} W")
            print(f"       DUF SCORE:       {duf_baseline:.4f}")

            # --- 3. METRICHE FISICHE ---
            ta, cons_a, ca, ra, slaa, faira = env._calculate_metrics(p_agentic, tr, p)
            tb, cons_b, cb, rb, slab, fairb = env._calculate_metrics(p_baseline, tr, p)

            # Save Data
            prefix = f"C{cid}"
            row_data[f'{prefix}_Traffic'] = tr
            row_data[f'{prefix}_Safety'] = safe

            # Salviamo i pesi per il plot
            row_data[f'{prefix}_W_Thr_A'] = wa_t
            row_data[f'{prefix}_W_Eng_A'] = wa_e
            row_data[f'{prefix}_W_Safe_A'] = wa_s

            row_data[f'{prefix}_Cons_A'] = cons_a
            row_data[f'{prefix}_Cons_B'] = cons_b
            row_data[f'{prefix}_Cost_A'] = ca
            row_data[f'{prefix}_Cost_B'] = cb
            row_data[f'{prefix}_Thr_A'] = ta
            row_data[f'{prefix}_Thr_B'] = tb
            row_data[f'{prefix}_Risk_A'] = ra
            row_data[f'{prefix}_Risk_B'] = rb

            # Save Advanced Metrics
            row_data[f'{prefix}_SLA_A'] = slaa
            row_data[f'{prefix}_Fair_A'] = faira
            row_data[f'{prefix}_SLA_B'] = slab
            row_data[f'{prefix}_Fair_B'] = fairb

        history.append(row_data)

    print(f"\n✅ Simulation Run {run_id} Completed.")

    # SALVATAGGIO FONDAMENTALE PER LA TABELLA
    df = pd.DataFrame(history)
    df.to_json(f"results_scenario3_run_{run_id}.json")
    return df

# ESECUZIONE
df_res = run_experiment_single(RUN_ID)
# Out:
# 🚀 STARTING SIMULATION RUN 1 (SCENARIO 3: DDoS)...
#
# ================================================================================
# ⏰ TIMESTEP 0 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1396
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2249
#
#   📍 CELL 2 [Load: 38.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    24.1 W
#        DUF SCORE:       0.0965
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2087
#
#   📍 CELL 3 [Load: 41.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1384
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2233
#
# ================================================================================
# ⏰ TIMESTEP 1 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 36.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.324, "w_eng": 0.676, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.32, W_Eng=0.68, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0418
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1939
#
#   📍 CELL 2 [Load: 35.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.35, "w_eng": 0.65, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.35, W_Eng=0.65, W_Safe=0.00
#        CHOSEN POWER:    19.6 W
#        DUF SCORE:       0.0461
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1892
#
#   📍 CELL 3 [Load: 31.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.69, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    14.0 W
#        DUF SCORE:       0.0313
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1658
#
# ================================================================================
# ⏰ TIMESTEP 2 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    25.2 W
#        DUF SCORE:       0.0993
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2133
#
#   📍 CELL 2 [Load: 35.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.324, "w_eng": 0.676, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.32, W_Eng=0.68, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0414
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1925
#
#   📍 CELL 3 [Load: 43.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1392
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2357
#
# ================================================================================
# ⏰ TIMESTEP 3 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    25.2 W
#        DUF SCORE:       0.0987
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2123
#
#   📍 CELL 2 [Load: 37.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.69, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0416
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2045
#
#   📍 CELL 3 [Load: 48.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.52, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.52, W_Safe=0.00
#        CHOSEN POWER:    46.5 W
#        DUF SCORE:       0.1202
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2648
#
# ================================================================================
# ⏰ TIMESTEP 4 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.1367
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2572
#
#   📍 CELL 2 [Load: 35.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.35, "w_eng": 0.65, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.35, W_Eng=0.65, W_Safe=0.00
#        CHOSEN POWER:    19.6 W
#        DUF SCORE:       0.0456
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1877
#
#   📍 CELL 3 [Load: 39.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 0.39, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=0.39, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1374
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2113
#
# ================================================================================
# ⏰ TIMESTEP 5 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1383
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2231
#
#   📍 CELL 2 [Load: 45.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0384
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2506
#
#   📍 CELL 3 [Load: 42.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.71, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.71, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0435
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2295
#
# ================================================================================
# ⏰ TIMESTEP 6 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0395
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2538
#
#   📍 CELL 2 [Load: 47.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0385
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2643
#
#   📍 CELL 3 [Load: 28.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.71, "w_eng": 1.00, "w_safe": 0.00}
#        DECIDED WEIGHTS: W_Thr=0.71, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    20.7 W
#        DUF SCORE:       0.0780
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1493
#
# ================================================================================
# ⏰ TIMESTEP 7 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 54.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.46, "w_eng": 0.54, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.46, W_Eng=0.54, W_Safe=0.00
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       0.1322
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3023
#
#   📍 CELL 2 [Load: 49.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1280
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2711
#
#   📍 CELL 3 [Load: 38.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.61, "w_safe": 0.08}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.61, W_Safe=0.08
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       0.0302
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2057
#
# ================================================================================
# ⏰ TIMESTEP 8 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 51.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    52.1 W
#        DUF SCORE:       0.1355
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2837
#
#   📍 CELL 2 [Load: 41.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.42, "w_safe": 0.29}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.42, W_Safe=0.29
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.0481
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2277
#
#   📍 CELL 3 [Load: 34.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.33, "w_eng": 0.66, "w_safe": 0.01}
#        DECIDED WEIGHTS: W_Thr=0.33, W_Eng=0.66, W_Safe=0.01
#        CHOSEN POWER:    23.0 W
#        DUF SCORE:       0.0354
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1845
#
# ================================================================================
# ⏰ TIMESTEP 9 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 43.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1400
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2369
#
#   📍 CELL 2 [Load: 47.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.265, "w_safe": 0.47}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.27, W_Safe=0.47
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0659
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2590
#
#   📍 CELL 3 [Load: 46.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0392
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2530
#
# ================================================================================
# ⏰ TIMESTEP 10 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0444
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2433
#
#   📍 CELL 2 [Load: 46.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0394
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2537
#
#   📍 CELL 3 [Load: 45.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1400
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2491
#
# ================================================================================
# ⏰ TIMESTEP 11 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 49.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1278
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2707
#
#   📍 CELL 2 [Load: 50.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0442
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2777
#
#   📍 CELL 3 [Load: 46.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.27, "w_safe": 0.46}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.27, W_Safe=0.46
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0655
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2540
#
# ================================================================================
# ⏰ TIMESTEP 12 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    25.2 W
#        DUF SCORE:       0.0981
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2113
#
#   📍 CELL 2 [Load: 49.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0433
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2740
#
#   📍 CELL 3 [Load: 45.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1392
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2478
#
# ================================================================================
# ⏰ TIMESTEP 13 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 43.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0433
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2389
#
#   📍 CELL 2 [Load: 48.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0391
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2671
#
#   📍 CELL 3 [Load: 53.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    26.3 W
#        DUF SCORE:       0.1049
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2947
#
# ================================================================================
# ⏰ TIMESTEP 14 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 51.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    52.1 W
#        DUF SCORE:       0.1349
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2827
#
#   📍 CELL 2 [Load: 39.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.312, "w_eng": 0.608, "w_safe": 0.08}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.61, W_Safe=0.08
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       0.0336
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2130
#
#   📍 CELL 3 [Load: 42.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0622
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2315
#
# ================================================================================
# ⏰ TIMESTEP 15 | Price Factor: 8.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 48.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.51, "w_eng": 0.49, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.51, W_Eng=0.49, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0477
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    25.2 W
#        DUF SCORE:       0.1616
#
#   📍 CELL 2 [Load: 48.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.72, "w_safe": 0.04}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.72, W_Safe=0.04
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0505
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    25.2 W
#        DUF SCORE:       0.1606
#
#   📍 CELL 3 [Load: 48.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.51, "w_eng": 0.49, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.51, W_Eng=0.49, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0481
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    25.2 W
#        DUF SCORE:       0.1628
#
# ================================================================================
# ⏰ TIMESTEP 16 | Price Factor: 6.19x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 59.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.41, "w_eng": 0.59, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.41, W_Eng=0.59, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0491
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    40.9 W
#        DUF SCORE:       0.2362
#
#   📍 CELL 2 [Load: 50.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.6, "w_safe": 0.15}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.60, W_Safe=0.15
#        CHOSEN POWER:    14.0 W
#        DUF SCORE:       -0.1301
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    34.2 W
#        DUF SCORE:       0.1882
#
#   📍 CELL 3 [Load: 52.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0548
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    36.4 W
#        DUF SCORE:       0.2007
#
# ================================================================================
# ⏰ TIMESTEP 17 | Price Factor: 4.84x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 47.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.735, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0109
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    40.9 W
#        DUF SCORE:       0.1890
#
#   📍 CELL 2 [Load: 46.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.26, "w_eng": 0.74, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.74, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0096
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    40.9 W
#        DUF SCORE:       0.1869
#
#   📍 CELL 3 [Load: 49.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0097
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    43.2 W
#        DUF SCORE:       0.2009
#
# ================================================================================
# ⏰ TIMESTEP 18 | Price Factor: 3.85x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 45.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0165
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    51.0 W
#        DUF SCORE:       0.1956
#
#   📍 CELL 2 [Load: 49.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0161
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    54.4 W
#        DUF SCORE:       0.2180
#
#   📍 CELL 3 [Load: 50.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.77, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.77, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0129
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.2232
#
# ================================================================================
# ⏰ TIMESTEP 19 | Price Factor: 3.11x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 47.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.735, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0214
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2177
#
#   📍 CELL 2 [Load: 45.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.725, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0213
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2055
#
#   📍 CELL 3 [Load: 47.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0283
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2196
#
# ================================================================================
# ⏰ TIMESTEP 20 | Price Factor: 2.56x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 52.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0246
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2590
#
#   📍 CELL 2 [Load: 50.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.245, "w_eng": 0.755, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0242
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2491
#
#   📍 CELL 3 [Load: 50.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.245, "w_eng": 0.755, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0241
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2487
#
# ================================================================================
# ⏰ TIMESTEP 21 | Price Factor: 2.16x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 52.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0277
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2656
#
#   📍 CELL 2 [Load: 55.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.225, "w_eng": 0.775, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.78, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0272
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2853
#
#   📍 CELL 3 [Load: 56.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.22, "w_eng": 0.78, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.22, W_Eng=0.78, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0269
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2916
#
# ================================================================================
# ⏰ TIMESTEP 22 | Price Factor: 1.86x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 64.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.175, "w_eng": 1.585, "w_safe": 0.24}
#        DECIDED WEIGHTS: W_Thr=0.17, W_Eng=1.58, W_Safe=0.24
#        CHOSEN POWER:    33.1 W
#        DUF SCORE:       -0.1478
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3461
#
#   📍 CELL 2 [Load: 63.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
# ...
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0084
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 43 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 77.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4405
#
#   📍 CELL 2 [Load: 67.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3819
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 44 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 64.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3593
#
#   📍 CELL 2 [Load: 62.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3480
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 45 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 64.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3634
#
#   📍 CELL 2 [Load: 66.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3740
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 46 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 64.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3648
#
#   📍 CELL 2 [Load: 68.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3871
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 47 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 73.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4153
#
#   📍 CELL 2 [Load: 67.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3823
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 48 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 62.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3530
#
#   📍 CELL 2 [Load: 77.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4387
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 49 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 75.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4251
#
#   📍 CELL 2 [Load: 72.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4125
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ✅ Simulation Run 1 Completed.

# %% [markdown]
# ## Run 2

# %%
# ==============================================================================
# 5. ESECUZIONE SIMULAZIONE (RUN SINGOLA) - SCENARIO 3 (DDoS)
# ==============================================================================

# --- CAMBIA QUESTO ID IN OGNI CELLA (0, 1, 2, 3, 4) ---
RUN_ID = 2
# ------------------------------------------------------

def run_experiment_single(run_id):
    env = ORAN3CellsEnv()
    steps = 50 # <-- Aumentato a 50 per mostrare il DDoS
    history = []

    # --- Generazione Scenari (SEED DIVERSO) ---
    np.random.seed(42 + run_id) # <--- Seed Variabile

    # 1. PREZZO
    prices = np.ones(steps)
    prices[15] = 8.0
    for t in range(16, steps): # <-- Arriva fino alla fine (50)
        prices[t] = 1.0 + 7.0 * np.exp(-0.3 * (t-15))

    # 2. TRAFFICO
    traffic_c = []
    base_trend = np.linspace(40, 70, steps)
    for i in range(3):
        noise = np.random.normal(0, 5, steps)
        tr = np.clip(base_trend + noise, 10, 100)
        traffic_c.append(tr)

    # --- INIZIO ATTACCO DDoS IN CELLA 3 (Indice 2) ---
    traffic_c[2][40:steps] = 100.0

    # 3. SAFETY (Disattivata in questo scenario)
    safety_c2 = np.zeros(steps)

    print(f"🚀 STARTING SIMULATION RUN {run_id} (SCENARIO 3: DDoS)...")

    for t in range(steps):
        p = prices[t]
        row_data = {'Step': t, 'Price': p}

        # --- CONTESTO ESTERNO (ALLERTA DDoS) ---
        if t >= 40:
            external_context = "IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3."
        else:
            external_context = "None"

        print(f"\n{'='*80}")
        print(f"⏰ TIMESTEP {t} | Price Factor: {p:.2f}x | Alert: {external_context}")
        print(f"{'='*80}")

        # Iteriamo sulle 3 Celle
        for i in range(3):
            cid = i + 1
            tr = traffic_c[i][t]
            safe = safety_c2[t]

            print(f"\n  📍 CELL {cid} [Load: {tr:.1f}% | Safety: {safe:.0f}]")

            # AGGIUNTO SLEEP PREVENTIVO (Mantenuto a 1.2s per stabilità API Mistral)
            time.sleep(1.2)

            # --- 1. A-LLM (Agentic) ---
            # AGGIUNTO IL SESTO PARAMETRO: external_context
            wa_t, wa_e, wa_s, prompt_txt, json_resp = get_llm_weights_per_cell(t, cid, p, tr, safe, external_context)
            p_agentic, duf_agentic = optimize_power(wa_t, wa_e, wa_s, p, tr, env)

            # LOG TRASPARENZA A-LLM
            print(f"    🔸 [A-LLM INTERACTION]")
            print(f"       PROMPT TAIL:     ...{json.dumps(prompt_txt.strip()[-200:])}")
            print(f"       OUTPUT JSON:     {json_resp}")
            print(f"       DECIDED WEIGHTS: W_Thr={wa_t:.2f}, W_Eng={wa_e:.2f}, W_Safe={wa_s:.2f}")
            print(f"       CHOSEN POWER:    {p_agentic:.1f} W")
            print(f"       DUF SCORE:       {duf_agentic:.4f}")

            # --- 2. DRL (Baseline) ---
            wb_t, wb_e, wb_s = 0.8, 0.2, 0.0
            p_baseline, duf_baseline = optimize_power(wb_t, wb_e, wb_s, p, tr, env)

            # LOG TRASPARENZA BASELINE
            print(f"    🔹 [BASELINE DRL]")
            print(f"       STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00")
            print(f"       CHOSEN POWER:    {p_baseline:.1f} W")
            print(f"       DUF SCORE:       {duf_baseline:.4f}")

            # --- 3. METRICHE FISICHE ---
            ta, cons_a, ca, ra, slaa, faira = env._calculate_metrics(p_agentic, tr, p)
            tb, cons_b, cb, rb, slab, fairb = env._calculate_metrics(p_baseline, tr, p)

            # Save Data
            prefix = f"C{cid}"
            row_data[f'{prefix}_Traffic'] = tr
            row_data[f'{prefix}_Safety'] = safe

            # Salviamo i pesi per il plot
            row_data[f'{prefix}_W_Thr_A'] = wa_t
            row_data[f'{prefix}_W_Eng_A'] = wa_e
            row_data[f'{prefix}_W_Safe_A'] = wa_s

            row_data[f'{prefix}_Cons_A'] = cons_a
            row_data[f'{prefix}_Cons_B'] = cons_b
            row_data[f'{prefix}_Cost_A'] = ca
            row_data[f'{prefix}_Cost_B'] = cb
            row_data[f'{prefix}_Thr_A'] = ta
            row_data[f'{prefix}_Thr_B'] = tb
            row_data[f'{prefix}_Risk_A'] = ra
            row_data[f'{prefix}_Risk_B'] = rb

            # Save Advanced Metrics
            row_data[f'{prefix}_SLA_A'] = slaa
            row_data[f'{prefix}_Fair_A'] = faira
            row_data[f'{prefix}_SLA_B'] = slab
            row_data[f'{prefix}_Fair_B'] = fairb

        history.append(row_data)

    print(f"\n✅ Simulation Run {run_id} Completed.")

    # SALVATAGGIO FONDAMENTALE PER LA TABELLA
    df = pd.DataFrame(history)
    df.to_json(f"results_scenario3_run_{run_id}.json")
    return df

# ESECUZIONE
df_res = run_experiment_single(RUN_ID)
# Out:
# 🚀 STARTING SIMULATION RUN 2 (SCENARIO 3: DDoS)...
#
# ================================================================================
# ⏰ TIMESTEP 0 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 36.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.36, "w_eng": 0.64, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.36, W_Eng=0.64, W_Safe=0.00
#        CHOSEN POWER:    20.7 W
#        DUF SCORE:       0.0503
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1950
#
#   📍 CELL 2 [Load: 45.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1397
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2486
#
#   📍 CELL 3 [Load: 47.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0383
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2632
#
# ================================================================================
# ⏰ TIMESTEP 1 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 47.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.53, "w_safe": 0.205}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.53, W_Safe=0.20
#        CHOSEN POWER:    56.6 W
#        DUF SCORE:       0.0406
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2599
#
#   📍 CELL 2 [Load: 47.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.52, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.52, W_Safe=0.00
#        CHOSEN POWER:    46.5 W
#        DUF SCORE:       0.1196
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2637
#
#   📍 CELL 3 [Load: 37.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.63, "w_eng": 0.37, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.63, W_Eng=0.37, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1376
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2017
#
# ================================================================================
# ⏰ TIMESTEP 2 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 47.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    56.6 W
#        DUF SCORE:       0.1395
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2614
#
#   📍 CELL 2 [Load: 41.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1404
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2259
#
#   📍 CELL 3 [Load: 45.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0384
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2506
#
# ================================================================================
# ⏰ TIMESTEP 3 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 33.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.33, "w_eng": 0.67, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.33, W_Eng=0.67, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0392
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1805
#
#   📍 CELL 2 [Load: 42.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.58, "w_safe": 0.13}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.58, W_Safe=0.13
#        CHOSEN POWER:    53.3 W
#        DUF SCORE:       0.0349
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2308
#
#   📍 CELL 3 [Load: 40.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0431
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2187
#
# ================================================================================
# ⏰ TIMESTEP 4 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 35.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.35, "w_eng": 0.65, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.35, W_Eng=0.65, W_Safe=0.00
#        CHOSEN POWER:    19.6 W
#        DUF SCORE:       0.0458
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1882
#
#   📍 CELL 2 [Load: 40.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0428
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2175
#
#   📍 CELL 3 [Load: 46.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0393
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2533
#
# ================================================================================
# ⏰ TIMESTEP 5 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 34.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.33, "w_eng": 0.67, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.33, W_Eng=0.67, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0403
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1845
#
#   📍 CELL 2 [Load: 44.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.1367
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2443
#
#   📍 CELL 3 [Load: 42.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1376
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2334
#
# ================================================================================
# ⏰ TIMESTEP 6 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 53.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1324
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2941
#
#   📍 CELL 2 [Load: 49.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.51, "w_eng": 0.49, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.51, W_Eng=0.49, W_Safe=0.00
#        CHOSEN POWER:    54.4 W
#        DUF SCORE:       0.1374
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2720
#
#   📍 CELL 3 [Load: 41.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.295, "w_eng": 0.705, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0437
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2256
#
# ================================================================================
# ⏰ TIMESTEP 7 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.1374
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2452
#
#   📍 CELL 2 [Load: 44.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0441
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2421
#
#   📍 CELL 3 [Load: 48.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1262
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2680
#
# ================================================================================
# ⏰ TIMESTEP 8 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.1370
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2447
#
#   📍 CELL 2 [Load: 44.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1381
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2463
#
#   📍 CELL 3 [Load: 32.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.34, "w_eng": 0.66, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.34, W_Eng=0.66, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0384
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1711
#
# ================================================================================
# ⏰ TIMESTEP 9 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 48.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.52, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.52, W_Safe=0.00
#        CHOSEN POWER:    47.7 W
#        DUF SCORE:       0.1211
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2664
#
#   📍 CELL 2 [Load: 42.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.58, "w_eng": 0.42, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.58, W_Eng=0.42, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1400
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2310
#
#   📍 CELL 3 [Load: 43.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.56, "w_eng": 0.44, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.56, W_Eng=0.44, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1369
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2384
#
# ================================================================================
# ⏰ TIMESTEP 10 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1397
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2250
#
#   📍 CELL 2 [Load: 54.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.46, "w_eng": 0.54, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.46, W_Eng=0.54, W_Safe=0.00
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       0.1315
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3008
#
#   📍 CELL 3 [Load: 46.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0392
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2529
#
# ================================================================================
# ⏰ TIMESTEP 11 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 45.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.54, "w_eng": 0.46, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.54, W_Eng=0.46, W_Safe=0.00
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.1375
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2518
#
#   📍 CELL 2 [Load: 46.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    56.6 W
#        DUF SCORE:       0.1371
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2577
#
#   📍 CELL 3 [Load: 48.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0390
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2665
#
# ================================================================================
# ⏰ TIMESTEP 12 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1402
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2257
#
#   📍 CELL 2 [Load: 50.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0441
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2775
#
#   📍 CELL 3 [Load: 44.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0441
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2421
#
# ================================================================================
# ⏰ TIMESTEP 13 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 51.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    52.1 W
#        DUF SCORE:       0.1347
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2824
#
#   📍 CELL 2 [Load: 47.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    56.6 W
#        DUF SCORE:       0.1376
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2585
#
#   📍 CELL 3 [Load: 38.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.69, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0420
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2057
#
# ================================================================================
# ⏰ TIMESTEP 14 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 43.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.56, "w_eng": 0.44, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.56, W_Eng=0.44, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1379
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2398
#
#   📍 CELL 2 [Load: 50.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    52.1 W
#        DUF SCORE:       0.1343
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2818
#
#   📍 CELL 3 [Load: 50.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0438
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2763
#
# ================================================================================
# ⏰ TIMESTEP 15 | Price Factor: 8.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 51.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.49, "w_safe": 0.02}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.49, W_Safe=0.02
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0293
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    26.3 W
#        DUF SCORE:       0.1731
#
#   📍 CELL 2 [Load: 40.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0078
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    20.7 W
#        DUF SCORE:       0.1228
#
#   📍 CELL 3 [Load: 43.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0517
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    21.8 W
#        DUF SCORE:       0.1358
#
# ================================================================================
# ⏰ TIMESTEP 16 | Price Factor: 6.19x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 55.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.45, "w_eng": 0.55, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.45, W_Eng=0.55, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0532
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    37.6 W
#        DUF SCORE:       0.2129
#
#   📍 CELL 2 [Load: 50.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0021
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    34.2 W
#        DUF SCORE:       0.1887
#
#   📍 CELL 3 [Load: 52.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.47, "w_safe": 0.06}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.47, W_Safe=0.06
#        CHOSEN POWER:    14.0 W
#        DUF SCORE:       0.0111
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    35.3 W
#        DUF SCORE:       0.2001
#
# ================================================================================
# ⏰ TIMESTEP 17 | Price Factor: 4.84x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 49.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.5, "w_eng": 0.44, "w_safe": 0.06}
#        DECIDED WEIGHTS: W_Thr=0.50, W_Eng=0.44, W_Safe=0.06
#        CHOSEN POWER:    21.8 W
#        DUF SCORE:       0.0341
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    43.2 W
#        DUF SCORE:       0.2026
#
#   📍 CELL 2 [Load: 47.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.26, "w_eng": 0.74, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.74, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0099
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    40.9 W
#        DUF SCORE:       0.1890
#
#   📍 CELL 3 [Load: 52.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0097
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    45.4 W
#        DUF SCORE:       0.2146
#
# ================================================================================
# ⏰ TIMESTEP 18 | Price Factor: 3.85x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 55.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.45, "w_eng": 0.55, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.45, W_Eng=0.55, W_Safe=0.00
#        CHOSEN POWER:    11.7 W
#        DUF SCORE:       0.0725
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2502
#
#   📍 CELL 2 [Load: 57.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.42, "w_eng": 0.385, "w_safe": 0.195}
#        DECIDED WEIGHTS: W_Thr=0.42, W_Eng=0.39, W_Safe=0.20
#        CHOSEN POWER:    47.7 W
#        DUF SCORE:       0.0419
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2645
#
#   📍 CELL 3 [Load: 50.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.245, "w_eng": 0.755, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0159
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.2235
#
# ================================================================================
# ⏰ TIMESTEP 19 | Price Factor: 3.11x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 45.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0209
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2082
#
#   📍 CELL 2 [Load: 55.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.44, "w_eng": 0.56, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.44, W_Eng=0.56, W_Safe=0.00
#        CHOSEN POWER:    14.0 W
#        DUF SCORE:       0.0787
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2671
#
#   📍 CELL 3 [Load: 59.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.41, "w_eng": 0.59, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.41, W_Eng=0.59, W_Safe=0.00
#        CHOSEN POWER:    12.9 W
#        DUF SCORE:       0.0754
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2879
#
# ================================================================================
# ⏰ TIMESTEP 20 | Price Factor: 2.56x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0252
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2233
#
#   📍 CELL 2 [Load: 50.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.245, "w_eng": 0.755, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0244
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2503
#
#   📍 CELL 3 [Load: 57.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.21, "w_eng": 0.79, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.21, W_Eng=0.79, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0224
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2921
#
# ================================================================================
# ⏰ TIMESTEP 21 | Price Factor: 2.16x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 54.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.77, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.77, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0272
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2769
#
#   📍 CELL 2 [Load: 49.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.255, "w_eng": 0.525, "w_safe": 0.22}
#        DECIDED WEIGHTS: W_Thr=0.26, W_Eng=0.53, W_Safe=0.22
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       -0.0126
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2489
#
#   📍 CELL 3 [Load: 47.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.53, "w_safe": 0.205}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.53, W_Safe=0.20
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       -0.0129
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2382
#
# ================================================================================
# ⏰ TIMESTEP 22 | Price Factor: 1.86x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 52.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.93, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.93, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0270
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2737
#
#   📍 CELL 2 [Load: 48.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
# ...
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0084
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 43 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 57.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3181
#
#   📍 CELL 2 [Load: 67.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3799
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 44 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 69.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3894
#
#   📍 CELL 2 [Load: 66.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3753
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 45 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 66.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3736
#
#   📍 CELL 2 [Load: 69.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3889
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 46 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 70.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3971
#
#   📍 CELL 2 [Load: 71.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4020
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 47 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 73.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4137
#
#   📍 CELL 2 [Load: 73.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4183
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 48 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 79.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4511
#
#   📍 CELL 2 [Load: 69.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3917
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 49 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 76.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4358
#
#   📍 CELL 2 [Load: 61.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3432
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ✅ Simulation Run 2 Completed.

# %% [markdown]
# ## Run 3

# %%
# ==============================================================================
# 5. ESECUZIONE SIMULAZIONE (RUN SINGOLA) - SCENARIO 3 (DDoS)
# ==============================================================================

# --- CAMBIA QUESTO ID IN OGNI CELLA (0, 1, 2, 3, 4) ---
RUN_ID = 3
# ------------------------------------------------------

def run_experiment_single(run_id):
    env = ORAN3CellsEnv()
    steps = 50 # <-- Aumentato a 50 per mostrare il DDoS
    history = []

    # --- Generazione Scenari (SEED DIVERSO) ---
    np.random.seed(42 + run_id) # <--- Seed Variabile

    # 1. PREZZO
    prices = np.ones(steps)
    prices[15] = 8.0
    for t in range(16, steps): # <-- Arriva fino alla fine (50)
        prices[t] = 1.0 + 7.0 * np.exp(-0.3 * (t-15))

    # 2. TRAFFICO
    traffic_c = []
    base_trend = np.linspace(40, 70, steps)
    for i in range(3):
        noise = np.random.normal(0, 5, steps)
        tr = np.clip(base_trend + noise, 10, 100)
        traffic_c.append(tr)

    # --- INIZIO ATTACCO DDoS IN CELLA 3 (Indice 2) ---
    traffic_c[2][40:steps] = 100.0

    # 3. SAFETY (Disattivata in questo scenario)
    safety_c2 = np.zeros(steps)

    print(f"🚀 STARTING SIMULATION RUN {run_id} (SCENARIO 3: DDoS)...")

    for t in range(steps):
        p = prices[t]
        row_data = {'Step': t, 'Price': p}

        # --- CONTESTO ESTERNO (ALLERTA DDoS) ---
        if t >= 40:
            external_context = "IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3."
        else:
            external_context = "None"

        print(f"\n{'='*80}")
        print(f"⏰ TIMESTEP {t} | Price Factor: {p:.2f}x | Alert: {external_context}")
        print(f"{'='*80}")

        # Iteriamo sulle 3 Celle
        for i in range(3):
            cid = i + 1
            tr = traffic_c[i][t]
            safe = safety_c2[t]

            print(f"\n  📍 CELL {cid} [Load: {tr:.1f}% | Safety: {safe:.0f}]")

            # AGGIUNTO SLEEP PREVENTIVO (Mantenuto a 1.2s per stabilità API Mistral)
            time.sleep(1.2)

            # --- 1. A-LLM (Agentic) ---
            # AGGIUNTO IL SESTO PARAMETRO: external_context
            wa_t, wa_e, wa_s, prompt_txt, json_resp = get_llm_weights_per_cell(t, cid, p, tr, safe, external_context)
            p_agentic, duf_agentic = optimize_power(wa_t, wa_e, wa_s, p, tr, env)

            # LOG TRASPARENZA A-LLM
            print(f"    🔸 [A-LLM INTERACTION]")
            print(f"       PROMPT TAIL:     ...{json.dumps(prompt_txt.strip()[-200:])}")
            print(f"       OUTPUT JSON:     {json_resp}")
            print(f"       DECIDED WEIGHTS: W_Thr={wa_t:.2f}, W_Eng={wa_e:.2f}, W_Safe={wa_s:.2f}")
            print(f"       CHOSEN POWER:    {p_agentic:.1f} W")
            print(f"       DUF SCORE:       {duf_agentic:.4f}")

            # --- 2. DRL (Baseline) ---
            wb_t, wb_e, wb_s = 0.8, 0.2, 0.0
            p_baseline, duf_baseline = optimize_power(wb_t, wb_e, wb_s, p, tr, env)

            # LOG TRASPARENZA BASELINE
            print(f"    🔹 [BASELINE DRL]")
            print(f"       STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00")
            print(f"       CHOSEN POWER:    {p_baseline:.1f} W")
            print(f"       DUF SCORE:       {duf_baseline:.4f}")

            # --- 3. METRICHE FISICHE ---
            ta, cons_a, ca, ra, slaa, faira = env._calculate_metrics(p_agentic, tr, p)
            tb, cons_b, cb, rb, slab, fairb = env._calculate_metrics(p_baseline, tr, p)

            # Save Data
            prefix = f"C{cid}"
            row_data[f'{prefix}_Traffic'] = tr
            row_data[f'{prefix}_Safety'] = safe

            # Salviamo i pesi per il plot
            row_data[f'{prefix}_W_Thr_A'] = wa_t
            row_data[f'{prefix}_W_Eng_A'] = wa_e
            row_data[f'{prefix}_W_Safe_A'] = wa_s

            row_data[f'{prefix}_Cons_A'] = cons_a
            row_data[f'{prefix}_Cons_B'] = cons_b
            row_data[f'{prefix}_Cost_A'] = ca
            row_data[f'{prefix}_Cost_B'] = cb
            row_data[f'{prefix}_Thr_A'] = ta
            row_data[f'{prefix}_Thr_B'] = tb
            row_data[f'{prefix}_Risk_A'] = ra
            row_data[f'{prefix}_Risk_B'] = rb

            # Save Advanced Metrics
            row_data[f'{prefix}_SLA_A'] = slaa
            row_data[f'{prefix}_Fair_A'] = faira
            row_data[f'{prefix}_SLA_B'] = slab
            row_data[f'{prefix}_Fair_B'] = fairb

        history.append(row_data)

    print(f"\n✅ Simulation Run {run_id} Completed.")

    # SALVATAGGIO FONDAMENTALE PER LA TABELLA
    df = pd.DataFrame(history)
    df.to_json(f"results_scenario3_run_{run_id}.json")
    return df

# ESECUZIONE
df_res = run_experiment_single(RUN_ID)
# Out:
# 🚀 STARTING SIMULATION RUN 3 (SCENARIO 3: DDoS)...
#
# ================================================================================
# ⏰ TIMESTEP 0 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 40.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.6, "w_eng": 0.4, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.60, W_Eng=0.40, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1385
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2180
#
#   📍 CELL 2 [Load: 38.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    24.1 W
#        DUF SCORE:       0.0972
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2098
#
#   📍 CELL 3 [Load: 40.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.6, "w_safe": 0.1}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.60, W_Safe=0.10
#        CHOSEN POWER:    51.0 W
#        DUF SCORE:       0.0329
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2201
#
# ================================================================================
# ⏰ TIMESTEP 1 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.294, "w_eng": 0.586, "w_safe": 0.12}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.59, W_Safe=0.12
#        CHOSEN POWER:    53.3 W
#        DUF SCORE:       0.0349
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2286
#
#   📍 CELL 2 [Load: 49.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1292
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2732
#
#   📍 CELL 3 [Load: 42.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1377
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2336
#
# ================================================================================
# ⏰ TIMESTEP 2 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 0.39, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=0.39, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1385
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2128
#
#   📍 CELL 2 [Load: 38.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.61, "w_safe": 0.08}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.61, W_Safe=0.08
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       0.0307
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2069
#
#   📍 CELL 3 [Load: 44.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0441
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2422
#
# ================================================================================
# ⏰ TIMESTEP 3 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 40.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1375
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2221
#
#   📍 CELL 2 [Load: 37.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.315, "w_eng": 0.63, "w_safe": 0.055}
#        DECIDED WEIGHTS: W_Thr=0.32, W_Eng=0.63, W_Safe=0.06
#        CHOSEN POWER:    44.3 W
#        DUF SCORE:       0.0298
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2012
#
#   📍 CELL 3 [Load: 45.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1405
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2498
#
# ================================================================================
# ⏰ TIMESTEP 4 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 36.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.36, "w_eng": 0.64, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.36, W_Eng=0.64, W_Safe=0.00
#        CHOSEN POWER:    20.7 W
#        DUF SCORE:       0.0500
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1940
#
#   📍 CELL 2 [Load: 43.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.56, "w_eng": 0.44, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.56, W_Eng=0.44, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1379
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2398
#
#   📍 CELL 3 [Load: 36.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.324, "w_eng": 0.676, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.32, W_Eng=0.68, W_Safe=0.00
#        CHOSEN POWER:    18.5 W
#        DUF SCORE:       0.0425
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1964
#
# ================================================================================
# ⏰ TIMESTEP 5 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 30.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.35, "w_eng": 0.65, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.35, W_Eng=0.65, W_Safe=0.00
#        CHOSEN POWER:    16.2 W
#        DUF SCORE:       0.0365
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1584
#
#   📍 CELL 2 [Load: 43.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.43, "w_eng": 0.57, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.43, W_Eng=0.57, W_Safe=0.00
#        CHOSEN POWER:    34.2 W
#        DUF SCORE:       0.0864
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2352
#
#   📍 CELL 3 [Load: 50.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    52.1 W
#        DUF SCORE:       0.1334
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2803
#
# ================================================================================
# ⏰ TIMESTEP 6 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 45.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.275, "w_safe": 0.45}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.28, W_Safe=0.45
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0645
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2476
#
#   📍 CELL 2 [Load: 47.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0385
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2643
#
#   📍 CELL 3 [Load: 40.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0430
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2183
#
# ================================================================================
# ⏰ TIMESTEP 7 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.6, "w_safe": 0.1}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.60, W_Safe=0.10
#        CHOSEN POWER:    51.0 W
#        DUF SCORE:       0.0317
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2168
#
#   📍 CELL 2 [Load: 36.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.324, "w_eng": 0.676, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.32, W_Eng=0.68, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0422
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1955
#
#   📍 CELL 3 [Load: 42.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1372
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2330
#
# ================================================================================
# ⏰ TIMESTEP 8 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.53, "w_safe": 0.205}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.53, W_Safe=0.20
#        CHOSEN POWER:    56.6 W
#        DUF SCORE:       0.0400
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2580
#
#   📍 CELL 2 [Load: 45.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1392
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2479
#
#   📍 CELL 3 [Load: 48.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.51, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.51, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1271
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2695
#
# ================================================================================
# ⏰ TIMESTEP 9 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 50.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0441
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2776
#
#   📍 CELL 2 [Load: 46.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.27, "w_safe": 0.46}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.27, W_Safe=0.46
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0652
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2530
#
#   📍 CELL 3 [Load: 37.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.63, "w_eng": 0.37, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.63, W_Eng=0.37, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1362
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1999
#
# ================================================================================
# ⏰ TIMESTEP 10 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0441
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2531
#
#   📍 CELL 2 [Load: 45.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0385
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2508
#
#   📍 CELL 3 [Load: 53.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1331
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2955
#
# ================================================================================
# ⏰ TIMESTEP 11 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 48.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0386
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2649
#
#   📍 CELL 2 [Load: 43.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1394
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2360
#
#   📍 CELL 3 [Load: 43.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0432
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2385
#
# ================================================================================
# ⏰ TIMESTEP 12 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 40.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0427
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2171
#
#   📍 CELL 2 [Load: 48.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0390
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2668
#
#   📍 CELL 3 [Load: 44.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.1375
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2455
#
# ================================================================================
# ⏰ TIMESTEP 13 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 52.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.48, "w_safe": 0.28}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.48, W_Safe=0.28
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.0450
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2882
#
#   📍 CELL 2 [Load: 54.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.46, "w_safe": 0.31}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.46, W_Safe=0.31
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.0464
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3001
#
#   📍 CELL 3 [Load: 60.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.6, "w_safe": 0.1}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.60, W_Safe=0.10
#        CHOSEN POWER:    54.4 W
#        DUF SCORE:       0.0753
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3370
#
# ================================================================================
# ⏰ TIMESTEP 14 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 39.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0424
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2161
#
#   📍 CELL 2 [Load: 49.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.51, "w_eng": 0.49, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.51, W_Eng=0.49, W_Safe=0.00
#        CHOSEN POWER:    54.4 W
#        DUF SCORE:       0.1365
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2706
#
#   📍 CELL 3 [Load: 40.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1368
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2211
#
# ================================================================================
# ⏰ TIMESTEP 15 | Price Factor: 8.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0493
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    24.1 W
#        DUF SCORE:       0.1529
#
#   📍 CELL 2 [Load: 50.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0096
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    26.3 W
#        DUF SCORE:       0.1684
#
#   📍 CELL 3 [Load: 40.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0077
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    20.7 W
#        DUF SCORE:       0.1231
#
# ================================================================================
# ⏰ TIMESTEP 16 | Price Factor: 6.19x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.45, "w_eng": 0.55, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.45, W_Eng=0.55, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0367
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    30.8 W
#        DUF SCORE:       0.1599
#
#   📍 CELL 2 [Load: 51.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.52, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.52, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0555
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    35.3 W
#        DUF SCORE:       0.1949
#
#   📍 CELL 3 [Load: 51.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.52, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.52, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0555
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    35.3 W
#        DUF SCORE:       0.1950
#
# ================================================================================
# ⏰ TIMESTEP 17 | Price Factor: 4.84x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 50.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.49, "w_safe": 0.02}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.49, W_Safe=0.02
#        CHOSEN POWER:    12.9 W
#        DUF SCORE:       0.0519
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    44.3 W
#        DUF SCORE:       0.2065
#
#   📍 CELL 2 [Load: 49.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0095
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    43.2 W
#        DUF SCORE:       0.1996
#
#   📍 CELL 3 [Load: 45.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.725, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0110
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    39.8 W
#        DUF SCORE:       0.1781
#
# ================================================================================
# ⏰ TIMESTEP 18 | Price Factor: 3.85x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 50.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0167
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.2223
#
#   📍 CELL 2 [Load: 47.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.2, "w_eng": 0.78, "w_safe": 0.02}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.78, W_Safe=0.02
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0142
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    52.1 W
#        DUF SCORE:       0.2064
#
#   📍 CELL 3 [Load: 46.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0169
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    51.0 W
#        DUF SCORE:       0.1982
#
# ================================================================================
# ⏰ TIMESTEP 19 | Price Factor: 3.11x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 43.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0211
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1982
#
#   📍 CELL 2 [Load: 53.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.311, "w_safe": 0.219}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.31, W_Safe=0.22
#        CHOSEN POWER:    54.4 W
#        DUF SCORE:       0.0911
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2534
#
#   📍 CELL 3 [Load: 50.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.49, "w_eng": 0.311, "w_safe": 0.199}
#        DECIDED WEIGHTS: W_Thr=0.49, W_Eng=0.31, W_Safe=0.20
#        CHOSEN POWER:    54.4 W
#        DUF SCORE:       0.0899
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2381
#
# ================================================================================
# ⏰ TIMESTEP 20 | Price Factor: 2.56x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 49.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.71, "w_safe": 0.04}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.71, W_Safe=0.04
#        CHOSEN POWER:    11.7 W
#        DUF SCORE:       -0.0099
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2406
#
#   📍 CELL 2 [Load: 59.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.2, "w_eng": 0.8, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.80, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0215
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3026
#
#   📍 CELL 3 [Load: 53.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.77, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.77, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0237
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2676
#
# ================================================================================
# ⏰ TIMESTEP 21 | Price Factor: 2.16x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 45.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0281
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2290
#
#   📍 CELL 2 [Load: 56.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.22, "w_eng": 0.78, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.22, W_Eng=0.78, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0267
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2897
#
#   📍 CELL 3 [Load: 51.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0274
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2633
#
# ================================================================================
# ⏰ TIMESTEP 22 | Price Factor: 1.86x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 50.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    8.4 W
#        DUF SCORE:       0.0313
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2614
#
#   📍 CELL 2 [Load: 52.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
# ...
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0084
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 43 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 62.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3484
#
#   📍 CELL 2 [Load: 63.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3565
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 44 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 63.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3575
#
#   📍 CELL 2 [Load: 65.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3666
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 45 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 66.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3763
#
#   📍 CELL 2 [Load: 62.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3501
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 46 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 61.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3424
#
#   📍 CELL 2 [Load: 71.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4016
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 47 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 67.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3799
#
#   📍 CELL 2 [Load: 70.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3989
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 48 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 75.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4250
#
#   📍 CELL 2 [Load: 57.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3201
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 49 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 63.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3554
#
#   📍 CELL 2 [Load: 74.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4237
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ✅ Simulation Run 3 Completed.

# %% [markdown]
# ## Run 4

# %%
# ==============================================================================
# 5. ESECUZIONE SIMULAZIONE (RUN SINGOLA) - SCENARIO 3 (DDoS)
# ==============================================================================

# --- CAMBIA QUESTO ID IN OGNI CELLA (0, 1, 2, 3, 4) ---
RUN_ID = 4
# ------------------------------------------------------

def run_experiment_single(run_id):
    env = ORAN3CellsEnv()
    steps = 50 # <-- Aumentato a 50 per mostrare il DDoS
    history = []

    # --- Generazione Scenari (SEED DIVERSO) ---
    np.random.seed(42 + run_id) # <--- Seed Variabile

    # 1. PREZZO
    prices = np.ones(steps)
    prices[15] = 8.0
    for t in range(16, steps): # <-- Arriva fino alla fine (50)
        prices[t] = 1.0 + 7.0 * np.exp(-0.3 * (t-15))

    # 2. TRAFFICO
    traffic_c = []
    base_trend = np.linspace(40, 70, steps)
    for i in range(3):
        noise = np.random.normal(0, 5, steps)
        tr = np.clip(base_trend + noise, 10, 100)
        traffic_c.append(tr)

    # --- INIZIO ATTACCO DDoS IN CELLA 3 (Indice 2) ---
    traffic_c[2][40:steps] = 100.0

    # 3. SAFETY (Disattivata in questo scenario)
    safety_c2 = np.zeros(steps)

    print(f"🚀 STARTING SIMULATION RUN {run_id} (SCENARIO 3: DDoS)...")

    for t in range(steps):
        p = prices[t]
        row_data = {'Step': t, 'Price': p}

        # --- CONTESTO ESTERNO (ALLERTA DDoS) ---
        if t >= 40:
            external_context = "IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3."
        else:
            external_context = "None"

        print(f"\n{'='*80}")
        print(f"⏰ TIMESTEP {t} | Price Factor: {p:.2f}x | Alert: {external_context}")
        print(f"{'='*80}")

        # Iteriamo sulle 3 Celle
        for i in range(3):
            cid = i + 1
            tr = traffic_c[i][t]
            safe = safety_c2[t]

            print(f"\n  📍 CELL {cid} [Load: {tr:.1f}% | Safety: {safe:.0f}]")

            # AGGIUNTO SLEEP PREVENTIVO (Mantenuto a 1.2s per stabilità API Mistral)
            time.sleep(1.2)

            # --- 1. A-LLM (Agentic) ---
            # AGGIUNTO IL SESTO PARAMETRO: external_context
            wa_t, wa_e, wa_s, prompt_txt, json_resp = get_llm_weights_per_cell(t, cid, p, tr, safe, external_context)
            p_agentic, duf_agentic = optimize_power(wa_t, wa_e, wa_s, p, tr, env)

            # LOG TRASPARENZA A-LLM
            print(f"    🔸 [A-LLM INTERACTION]")
            print(f"       PROMPT TAIL:     ...{json.dumps(prompt_txt.strip()[-200:])}")
            print(f"       OUTPUT JSON:     {json_resp}")
            print(f"       DECIDED WEIGHTS: W_Thr={wa_t:.2f}, W_Eng={wa_e:.2f}, W_Safe={wa_s:.2f}")
            print(f"       CHOSEN POWER:    {p_agentic:.1f} W")
            print(f"       DUF SCORE:       {duf_agentic:.4f}")

            # --- 2. DRL (Baseline) ---
            wb_t, wb_e, wb_s = 0.8, 0.2, 0.0
            p_baseline, duf_baseline = optimize_power(wb_t, wb_e, wb_s, p, tr, env)

            # LOG TRASPARENZA BASELINE
            print(f"    🔹 [BASELINE DRL]")
            print(f"       STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00")
            print(f"       CHOSEN POWER:    {p_baseline:.1f} W")
            print(f"       DUF SCORE:       {duf_baseline:.4f}")

            # --- 3. METRICHE FISICHE ---
            ta, cons_a, ca, ra, slaa, faira = env._calculate_metrics(p_agentic, tr, p)
            tb, cons_b, cb, rb, slab, fairb = env._calculate_metrics(p_baseline, tr, p)

            # Save Data
            prefix = f"C{cid}"
            row_data[f'{prefix}_Traffic'] = tr
            row_data[f'{prefix}_Safety'] = safe

            # Salviamo i pesi per il plot
            row_data[f'{prefix}_W_Thr_A'] = wa_t
            row_data[f'{prefix}_W_Eng_A'] = wa_e
            row_data[f'{prefix}_W_Safe_A'] = wa_s

            row_data[f'{prefix}_Cons_A'] = cons_a
            row_data[f'{prefix}_Cons_B'] = cons_b
            row_data[f'{prefix}_Cost_A'] = ca
            row_data[f'{prefix}_Cost_B'] = cb
            row_data[f'{prefix}_Thr_A'] = ta
            row_data[f'{prefix}_Thr_B'] = tb
            row_data[f'{prefix}_Risk_A'] = ra
            row_data[f'{prefix}_Risk_B'] = rb

            # Save Advanced Metrics
            row_data[f'{prefix}_SLA_A'] = slaa
            row_data[f'{prefix}_Fair_A'] = faira
            row_data[f'{prefix}_SLA_B'] = slab
            row_data[f'{prefix}_Fair_B'] = fairb

        history.append(row_data)

    print(f"\n✅ Simulation Run {run_id} Completed.")

    # SALVATAGGIO FONDAMENTALE PER LA TABELLA
    df = pd.DataFrame(history)
    df.to_json(f"results_scenario3_run_{run_id}.json")
    return df

# ESECUZIONE
df_res = run_experiment_single(RUN_ID)
# Out:
# 🚀 STARTING SIMULATION RUN 4 (SCENARIO 3: DDoS)...
#
# ================================================================================
# ⏰ TIMESTEP 0 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 42.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1384
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2346
#
#   📍 CELL 2 [Load: 43.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0433
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2388
#
#   📍 CELL 3 [Load: 39.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.312, "w_eng": 0.688, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    18.5 W
#        DUF SCORE:       0.0439
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2111
#
# ================================================================================
# ⏰ TIMESTEP 1 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.53, "w_safe": 0.205}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.53, W_Safe=0.20
#        CHOSEN POWER:    56.6 W
#        DUF SCORE:       0.0398
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2574
#
#   📍 CELL 2 [Load: 35.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.35, "w_eng": 0.65, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.35, W_Eng=0.65, W_Safe=0.00
#        CHOSEN POWER:    19.6 W
#        DUF SCORE:       0.0455
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1873
#
#   📍 CELL 3 [Load: 37.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.62, "w_eng": 0.38, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.62, W_Eng=0.38, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1360
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2045
#
# ================================================================================
# ⏰ TIMESTEP 2 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 45.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.275, "w_safe": 0.45}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.28, W_Safe=0.45
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0649
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2489
#
#   📍 CELL 2 [Load: 34.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.33, "w_eng": 0.66, "w_safe": 0.01}
#        DECIDED WEIGHTS: W_Thr=0.33, W_Eng=0.66, W_Safe=0.01
#        CHOSEN POWER:    23.0 W
#        DUF SCORE:       0.0347
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1824
#
#   📍 CELL 3 [Load: 42.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1374
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2332
#
# ================================================================================
# ⏰ TIMESTEP 3 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 37.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.69, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0416
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2044
#
#   📍 CELL 2 [Load: 52.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    49.9 W
#        DUF SCORE:       0.1313
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2922
#
#   📍 CELL 3 [Load: 32.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.34, "w_eng": 0.66, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.34, W_Eng=0.66, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0380
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1696
#
# ================================================================================
# ⏰ TIMESTEP 4 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.275, "w_safe": 0.45}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.28, W_Safe=0.45
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0632
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2440
#
#   📍 CELL 2 [Load: 33.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.33, "w_eng": 0.67, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.33, W_Eng=0.67, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0389
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1797
#
#   📍 CELL 3 [Load: 47.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0384
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2637
#
# ================================================================================
# ⏰ TIMESTEP 5 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 42.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.58, "w_safe": 0.13}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.58, W_Safe=0.13
#        CHOSEN POWER:    53.3 W
#        DUF SCORE:       0.0347
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2302
#
#   📍 CELL 2 [Load: 46.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.1363
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2565
#
#   📍 CELL 3 [Load: 38.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.31, "w_eng": 0.69, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.31, W_Eng=0.69, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0418
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2052
#
# ================================================================================
# ⏰ TIMESTEP 6 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 43.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1400
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2368
#
#   📍 CELL 2 [Load: 40.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.7, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.70, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0431
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2185
#
#   📍 CELL 3 [Load: 40.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1369
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2212
#
# ================================================================================
# ⏰ TIMESTEP 7 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.59, "w_eng": 0.41, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.59, W_Eng=0.41, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1403
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2259
#
#   📍 CELL 2 [Load: 45.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.54, "w_safe": 0.19}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.54, W_Safe=0.19
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.0383
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2503
#
#   📍 CELL 3 [Load: 42.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.58, "w_safe": 0.13}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.58, W_Safe=0.13
#        CHOSEN POWER:    53.3 W
#        DUF SCORE:       0.0344
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2294
#
# ================================================================================
# ⏰ TIMESTEP 8 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0445
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2435
#
#   📍 CELL 2 [Load: 50.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.5, "w_eng": 0.5, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.50, W_Eng=0.50, W_Safe=0.00
#        CHOSEN POWER:    53.3 W
#        DUF SCORE:       0.1361
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2773
#
#   📍 CELL 3 [Load: 43.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0436
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2402
#
# ================================================================================
# ⏰ TIMESTEP 9 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 49.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0436
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2753
#
#   📍 CELL 2 [Load: 35.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.36, "w_eng": 0.64, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.36, W_Eng=0.64, W_Safe=0.00
#        CHOSEN POWER:    20.7 W
#        DUF SCORE:       0.0496
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1929
#
#   📍 CELL 3 [Load: 43.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.57, "w_eng": 0.43, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.57, W_Eng=0.43, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.1408
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2379
#
# ================================================================================
# ⏰ TIMESTEP 10 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 41.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.29, "w_eng": 0.29, "w_safe": 0.42}
#        DECIDED WEIGHTS: W_Thr=0.29, W_Eng=0.29, W_Safe=0.42
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0609
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2280
#
#   📍 CELL 2 [Load: 45.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    58.9 W
#        DUF SCORE:       0.1401
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2492
#
#   📍 CELL 3 [Load: 47.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.265, "w_eng": 0.265, "w_safe": 0.47}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.27, W_Safe=0.47
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0658
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2585
#
# ================================================================================
# ⏰ TIMESTEP 11 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    56.6 W
#        DUF SCORE:       0.1370
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2577
#
#   📍 CELL 2 [Load: 53.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.46, "w_safe": 0.31}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.46, W_Safe=0.31
#        CHOSEN POWER:    57.8 W
#        DUF SCORE:       0.0457
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2976
#
#   📍 CELL 3 [Load: 45.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.275, "w_safe": 0.45}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.28, W_Safe=0.45
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.0641
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2466
#
# ================================================================================
# ⏰ TIMESTEP 12 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 55.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.45, "w_eng": 0.55, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.45, W_Eng=0.55, W_Safe=0.00
#        CHOSEN POWER:    47.7 W
#        DUF SCORE:       0.1302
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3072
#
#   📍 CELL 2 [Load: 52.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.52, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.52, W_Safe=0.00
#        CHOSEN POWER:    51.0 W
#        DUF SCORE:       0.1341
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2892
#
#   📍 CELL 3 [Load: 57.7% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.21, "w_eng": 0.79, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.21, W_Eng=0.79, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0408
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3222
#
# ================================================================================
# ⏰ TIMESTEP 13 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 45.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0435
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2505
#
#   📍 CELL 2 [Load: 58.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.21, "w_eng": 0.79, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.21, W_Eng=0.79, W_Safe=0.00
#        CHOSEN POWER:    16.2 W
#        DUF SCORE:       0.0415
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3256
#
#   📍 CELL 3 [Load: 46.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    56.6 W
#        DUF SCORE:       0.1370
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2576
#
# ================================================================================
# ⏰ TIMESTEP 14 | Price Factor: 1.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 46.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    55.5 W
#        DUF SCORE:       0.1362
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2564
#
#   📍 CELL 2 [Load: 44.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.28, "w_eng": 0.72, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.72, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0442
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2426
#
#   📍 CELL 3 [Load: 50.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0439
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2764
#
# ================================================================================
# ⏰ TIMESTEP 15 | Price Factor: 8.00x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 53.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0456
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    27.4 W
#        DUF SCORE:       0.1841
#
#   📍 CELL 2 [Load: 47.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.53, "w_eng": 0.47, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.53, W_Eng=0.47, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0502
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    24.1 W
#        DUF SCORE:       0.1552
#
#   📍 CELL 3 [Load: 39.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.61, "w_eng": 0.39, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.61, W_Eng=0.39, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0536
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    20.7 W
#        DUF SCORE:       0.1193
#
# ================================================================================
# ⏰ TIMESTEP 16 | Price Factor: 6.19x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 50.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0019
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    34.2 W
#        DUF SCORE:       0.1873
#
#   📍 CELL 2 [Load: 48.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.4, "w_eng": 0.6, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.40, W_Eng=0.60, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0322
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    33.1 W
#        DUF SCORE:       0.1806
#
#   📍 CELL 3 [Load: 49.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0014
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    34.2 W
#        DUF SCORE:       0.1840
#
# ================================================================================
# ⏰ TIMESTEP 17 | Price Factor: 4.84x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 49.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0101
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    43.2 W
#        DUF SCORE:       0.2031
#
#   📍 CELL 2 [Load: 51.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.48, "w_eng": 0.48, "w_safe": 0.04}
#        DECIDED WEIGHTS: W_Thr=0.48, W_Eng=0.48, W_Safe=0.04
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0394
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    45.4 W
#        DUF SCORE:       0.2133
#
#   📍 CELL 3 [Load: 46.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.27, "w_eng": 0.73, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.27, W_Eng=0.73, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0109
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    40.9 W
#        DUF SCORE:       0.1833
#
# ================================================================================
# ⏰ TIMESTEP 18 | Price Factor: 3.85x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 59.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.41, "w_eng": 0.59, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.41, W_Eng=0.59, W_Safe=0.00
#        CHOSEN POWER:    10.6 W
#        DUF SCORE:       0.0671
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2738
#
#   📍 CELL 2 [Load: 48.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.2, "w_eng": 0.78, "w_safe": 0.02}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.78, W_Safe=0.02
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0139
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    53.3 W
#        DUF SCORE:       0.2092
#
#   📍 CELL 3 [Load: 60.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.3, "w_eng": 0.69, "w_safe": 0.01}
#        DECIDED WEIGHTS: W_Thr=0.30, W_Eng=0.69, W_Safe=0.01
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0283
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2843
#
# ================================================================================
# ⏰ TIMESTEP 19 | Price Factor: 3.11x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 44.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.55, "w_eng": 0.45, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.55, W_Eng=0.45, W_Safe=0.00
#        CHOSEN POWER:    18.5 W
#        DUF SCORE:       0.0893
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2044
#
#   📍 CELL 2 [Load: 49.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.51, "w_eng": 0.49, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.51, W_Eng=0.49, W_Safe=0.00
#        CHOSEN POWER:    17.3 W
#        DUF SCORE:       0.0873
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2289
#
#   📍 CELL 3 [Load: 52.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.47, "w_eng": 0.53, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.47, W_Eng=0.53, W_Safe=0.00
#        CHOSEN POWER:    15.1 W
#        DUF SCORE:       0.0824
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2497
#
# ================================================================================
# ⏰ TIMESTEP 20 | Price Factor: 2.56x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 51.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.24, "w_eng": 0.76, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.24, W_Eng=0.76, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0240
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2546
#
#   📍 CELL 2 [Load: 50.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.2, "w_eng": 0.8, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.20, W_Eng=0.80, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       0.0153
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2459
#
#   📍 CELL 3 [Load: 56.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.22, "w_eng": 0.78, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.22, W_Eng=0.78, W_Safe=0.00
#        CHOSEN POWER:    6.1 W
#        DUF SCORE:       0.0235
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2832
#
# ================================================================================
# ⏰ TIMESTEP 21 | Price Factor: 2.16x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 50.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.25, "w_eng": 0.75, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.25, W_Eng=0.75, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0285
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2562
#
#   📍 CELL 2 [Load: 53.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.23, "w_eng": 0.77, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.23, W_Eng=0.77, W_Safe=0.00
#        CHOSEN POWER:    7.2 W
#        DUF SCORE:       0.0268
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2747
#
#   📍 CELL 3 [Load: 59.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.41, "w_eng": 0.59, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.41, W_Eng=0.59, W_Safe=0.00
#        CHOSEN POWER:    19.6 W
#        DUF SCORE:       0.0910
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3084
#
# ================================================================================
# ⏰ TIMESTEP 22 | Price Factor: 1.86x | Alert: None
# ================================================================================
#
#   📍 CELL 1 [Load: 45.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.275, "w_eng": 0.55, "w_safe": 0.175}
#        DECIDED WEIGHTS: W_Thr=0.28, W_Eng=0.55, W_Safe=0.17
#        CHOSEN POWER:    48.8 W
#        DUF SCORE:       -0.0022
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.2327
#
#   📍 CELL 2 [Load: 54.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
# ...
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0084
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 43 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 64.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3617
#
#   📍 CELL 2 [Load: 69.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3916
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5730
#
# ================================================================================
# ⏰ TIMESTEP 44 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 66.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3724
#
#   📍 CELL 2 [Load: 72.9% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4121
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 45 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 69.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3939
#
#   📍 CELL 2 [Load: 64.5% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3623
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 46 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 74.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4195
#
#   📍 CELL 2 [Load: 66.6% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3752
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 47 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 67.1% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3780
#
#   📍 CELL 2 [Load: 70.4% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3976
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 48 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 68.8% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3881
#
#   📍 CELL 2 [Load: 70.3% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3969
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ================================================================================
# ⏰ TIMESTEP 49 | Price Factor: 1.00x | Alert: IDS ALERT: Anomalous traffic signature detected. Potential DDoS originating from Cell 3.
# ================================================================================
#
#   📍 CELL 1 [Load: 79.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.4496
#
#   📍 CELL 2 [Load: 65.2% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.3668
#
#   📍 CELL 3 [Load: 100.0% | Safety: 0]
#     🔸 [A-LLM INTERACTION]
#        PROMPT TAIL:     ..."cted -> (w_eng = 1.0, w_thr = 0.0, w_safe = 0.0).\n    2. Emergency (>80): w_safe = 1.0.\n    3. Normal: Balance w_thr and w_eng.\n\n    Output JSON ONLY: {\"w_thr\": float, \"w_eng\": float, \"w_safe\": float}"
#        OUTPUT JSON:     {"w_thr": 0.0, "w_eng": 1.0, "w_safe": 0.0}
#        DECIDED WEIGHTS: W_Thr=0.00, W_Eng=1.00, W_Safe=0.00
#        CHOSEN POWER:    5.0 W
#        DUF SCORE:       -0.0083
#     🔹 [BASELINE DRL]
#        STATIC WEIGHTS:  W_Thr=0.80, W_Eng=0.20, W_Safe=0.00
#        CHOSEN POWER:    60.0 W
#        DUF SCORE:       0.5731
#
# ✅ Simulation Run 4 Completed.

# %% [markdown]
# # Generazione tabella latex

# %%
# ==============================================================================
# CELLA 3: GENERATORE TABELLA (SCENARIO 3 - DDoS)
# ==============================================================================
import pandas as pd
import numpy as np

def generate_paper_table_structural_sep(num_runs_to_analyze):
    RECALC_SLA_THR = 330.0

    # Cambiato 'Emerg' in 'DDoS'
    results = {
        'Shock': {1: {}, 2: {}, 3: {}, 'Global': {}},
        'DDoS':  {1: {}, 2: {}, 3: {}, 'Global': {}}
    }

    for evt in ['Shock', 'DDoS']:
        for c in [1, 2, 3, 'Global']:
            for m in ['Base', 'Agent']:
                results[evt][c][m] = {'thr':[], 'cost':[], 'pwr':[], 'sla':[], 'risk':[]}

    print(f"📊 Processing {num_runs_to_analyze} runs for Scenario 3...")

    for i in range(num_runs_to_analyze):
        # Aggiornato il nome del file per leggere i dati dello Scenario 3
        fname = f"results_scenario3_run_{i}.json"
        try:
            df = pd.read_json(fname)
        except:
            print(f"⚠️ Run {i} not found. Skipping...")
            continue

        # Finestre temporali aggiornate per lo Scenario 3
        df_Shock = df[(df['Step'] >= 15) & (df['Step'] < 30)]
        df_DDoS  = df[(df['Step'] >= 40) & (df['Step'] <= 50)] # DDoS da 40 a 50

        events = {'Shock': df_Shock, 'DDoS': df_DDoS}

        for evt_name, df_cut in events.items():
            # Controllo di sicurezza se il dataframe è vuoto
            if df_cut.empty:
                continue

            for cid in [1, 2, 3]:
                pre = f"C{cid}"
                traf_col = f'{pre}_Traffic'
                for m_type, suffix in [('Base', '_B'), ('Agent', '_A')]:
                    thr_col = f'{pre}_Thr{suffix}'

                    results[evt_name][cid][m_type]['thr'].append(df_cut[thr_col].mean())
                    results[evt_name][cid][m_type]['cost'].append(df_cut[f'{pre}_Cost{suffix}'].mean())
                    results[evt_name][cid][m_type]['pwr'].append(df_cut[f'{pre}_Cons{suffix}'].mean())
                    results[evt_name][cid][m_type]['risk'].append(df_cut[f'{pre}_Risk{suffix}'].mean())

                    # Calcolo SLA (0 o 1 per step)
                    sla_series = ((df_cut[thr_col] < RECALC_SLA_THR) & (df_cut[traf_col] > 10.0)).astype(float)
                    results[evt_name][cid][m_type]['sla'].append(sla_series.mean())

            for m_type, suffix in [('Base', '_B'), ('Agent', '_A')]:
                # Globali
                mean_thr = df_cut[[f'C{k}_Thr{suffix}' for k in [1,2,3]]].mean().mean()
                mean_cost = df_cut[[f'C{k}_Cost{suffix}' for k in [1,2,3]]].mean().mean()
                mean_pwr = df_cut[[f'C{k}_Cons{suffix}' for k in [1,2,3]]].mean().mean()
                mean_risk = df_cut[[f'C{k}_Risk{suffix}' for k in [1,2,3]]].mean().mean()

                sla_vals = []
                for k in [1, 2, 3]:
                    s = ((df_cut[f'C{k}_Thr{suffix}'] < RECALC_SLA_THR) & (df_cut[f'C{k}_Traffic'] > 10.0)).astype(float)
                    sla_vals.append(s.mean())
                mean_sla = np.mean(sla_vals)

                results[evt_name]['Global'][m_type]['thr'].append(mean_thr)
                results[evt_name]['Global'][m_type]['cost'].append(mean_cost)
                results[evt_name]['Global'][m_type]['pwr'].append(mean_pwr)
                results[evt_name]['Global'][m_type]['sla'].append(mean_sla)
                results[evt_name]['Global'][m_type]['risk'].append(mean_risk)

    # --- FORMATTERS ---
    def fmt(vals, is_pct=False, is_cost=False, is_decimal=False, bold=False):
        if not vals or np.isnan(np.mean(vals)): return "-"
        mu = np.mean(vals)
        sigma = np.std(vals)
        txt = ""

        if is_decimal:
            txt = f"{mu:.2f}"
        elif is_pct:
            txt = f"{mu*100:.1f}"
        elif is_cost:
            txt = f"{mu:.0f}"
        else:
            if sigma < 0.1: txt = f"{mu:.1f}"
            else: txt = f"{mu:.1f} $\\pm$ {sigma:.1f}"

        if bold: return f"\\textbf{{{txt}}}"
        return txt

    def get_diff_str(base_vals, agent_vals, metric_type='lower_better', is_absolute_delta=False):
        if not base_vals or not agent_vals: return "-"
        b = np.mean(base_vals)
        a = np.mean(agent_vals)
        if b == 0 and not is_absolute_delta: return "-"

        txt = ""
        is_improvement = False

        if is_absolute_delta:
            delta = a - b
            txt = f"{delta:+.2f}"
            if metric_type == 'lower_better' and delta < -0.001: is_improvement = True
            if metric_type == 'higher_better' and delta > 0.001: is_improvement = True
        else:
            delta = ((a - b) / b) * 100
            txt = f"{delta:+.1f}\\%"
            if metric_type == 'lower_better' and delta < -0.1: is_improvement = True
            if metric_type == 'higher_better' and delta > 0.1: is_improvement = True

        if is_improvement: return f"\\textbf{{{txt}}}"
        return txt

    def check_winner(base_vals, agent_vals, metric_type):
        if not base_vals or not agent_vals: return False, False
        b = np.mean(base_vals)
        a = np.mean(agent_vals)
        if metric_type == 'lower_better': return (a < b), (b < a)
        else: return (a > b), (b > a)

    # --- STAMPA TABELLA ---
    print("\n\n% === COPY THIS TABLE ===\n")
    print(r"\begin{table*}[t]")
    print(r"\centering")
    # Titolo aggiornato per lo Scenario C/3
    print(r"\caption{Scenario 3 Analysis: Comparative Results for Energy Crisis and DDoS Attack Events across 3 Cells}")
    print(r"\label{tab:detailed_results_scenario3}")
    print(r"\resizebox{\textwidth}{!}{%")
    print(r"\scriptsize")

    print(r"\begin{tabular}{clccccc}")
    print(r"\toprule")

    print(r"\textbf{Event} & \textbf{Method} & \textbf{Throughput} & \textbf{Energy Cost} & \textbf{Power} & \textbf{SLA Viol.} & \textbf{Safety Risk} \\")
    print(r" & & (Mbps) & (Units) & (Watts) & (Ratio 0-1) & (Prob.) \\")

    # Etichette Eventi Aggiornate
    event_labels = {'Shock': r"\textbf{Global Energy Crisis (Step 15-30)}",
                    'DDoS': r"\textbf{Localized DDoS Attack in Cell 3 (Step 40-50)}"}

    for i, evt in enumerate(['Shock', 'DDoS']):

        # TOPRULE richiesta sopra il secondo evento, MIDRULE altrove
        if i == 0:
            print(r"\midrule")
        else:
            print(r"\toprule")

        print(f"\\multicolumn{{7}}{{l}}{{{event_labels[evt]}}} \\\\")
        print(r"\midrule")

        for k in [1, 2, 3, 'Global']:
            b = results[evt][k]['Base']
            a = results[evt][k]['Agent']

            if k != 1:
                print(r"\midrule")

            if k == 'Global':
                row_label = r"\textbf{Network Avg}"
            else:
                row_label = f"Cell {k}"
                # Evidenziazione della Cella 3 durante il DDoS
                if evt == 'DDoS' and k == 3: row_label += r" \textit{(Attacked)}"

            w_thr_a, w_thr_b = check_winner(b['thr'], a['thr'], 'higher_better')
            w_cost_a, w_cost_b = check_winner(b['cost'], a['cost'], 'lower_better')
            w_pwr_a, w_pwr_b = check_winner(b['pwr'], a['pwr'], 'lower_better')
            w_sla_a, w_sla_b = check_winner(b['sla'], a['sla'], 'lower_better')
            w_risk_a, w_risk_b = check_winner(b['risk'], a['risk'], 'lower_better')

            print(f"\\multirow{{3}}{{*}}{{{row_label}}} & Baseline & "
                  f"{fmt(b['thr'], bold=w_thr_b)} & {fmt(b['cost'], is_cost=True, bold=w_cost_b)} & "
                  f"{fmt(b['pwr'], bold=w_pwr_b)} & {fmt(b['sla'], is_decimal=True, bold=w_sla_b)} & "
                  f"{fmt(b['risk'], is_decimal=True, bold=w_risk_b)} \\\\")

            print(f" & \\textbf{{A-LLM (Ours)}} & "
                  f"{fmt(a['thr'], bold=w_thr_a)} & {fmt(a['cost'], is_cost=True, bold=w_cost_a)} & "
                  f"{fmt(a['pwr'], bold=w_pwr_a)} & {fmt(a['sla'], is_decimal=True, bold=w_sla_a)} & "
                  f"{fmt(a['risk'], is_decimal=True, bold=w_risk_a)} \\\\")

            d_thr = get_diff_str(b['thr'], a['thr'], 'higher_better')
            d_cost = get_diff_str(b['cost'], a['cost'], 'lower_better')
            d_pwr = get_diff_str(b['pwr'], a['pwr'], 'lower_better')
            d_sla = get_diff_str(b['sla'], a['sla'], 'lower_better', is_absolute_delta=True)
            d_risk = get_diff_str(b['risk'], a['risk'], 'lower_better', is_absolute_delta=True)

            print(f" & \\textit{{Diff.}} & "
                  f"\\textit{{{d_thr}}} & \\textit{{{d_cost}}} & \\textit{{{d_pwr}}} & "
                  f"\\textit{{{d_sla}}} & {d_risk} \\\\")

    print(r"\bottomrule")
    print(r"\end{tabular}%")
    print(r"}")
    print(r"\vspace{0.1cm}")
    print(r"\\ \footnotesize{\textit{Note: Diff. row shows percentage change for Thr/Cost/Power, and absolute difference ($\Delta$) for SLA/Risk. Bold indicates the superior metric.}}")
    print(r"\end{table*}")

# Esecuzione: Analizza la prima run (o quante ne hai generate)
generate_paper_table_structural_sep(1)
# Out:
# 📊 Processing 1 runs for Scenario 3...
#
#
# % === COPY THIS TABLE ===
#
# \begin{table*}[t]
# \centering
# \caption{Scenario 3 Analysis: Comparative Results for Energy Crisis and DDoS Attack Events across 3 Cells}
# \label{tab:detailed_results_scenario3}
# \resizebox{\textwidth}{!}{%
# \scriptsize
# \begin{tabular}{clccccc}
# \toprule
# \textbf{Event} & \textbf{Method} & \textbf{Throughput} & \textbf{Energy Cost} & \textbf{Power} & \textbf{SLA Viol.} & \textbf{Safety Risk} \\
#  & & (Mbps) & (Units) & (Watts) & (Ratio 0-1) & (Prob.) \\
# \midrule
# \multicolumn{7}{l}{\textbf{Global Energy Crisis (Step 15-30)}} \\
# \midrule
# \multirow{3}{*}{Cell 1} & Baseline & \textbf{296.8} & 129 & 54.1 & \textbf{0.73} & \textbf{0.05} \\
#  & \textbf{A-LLM (Ours)} & 199.0 & \textbf{35} & \textbf{17.8} & 0.93 & 0.67 \\
#  & \textit{Diff.} & \textit{-33.0\%} & \textit{\textbf{-73.2\%}} & \textit{\textbf{-67.1\%}} & \textit{+0.20} & +0.62 \\
# \midrule
# \multirow{3}{*}{Cell 2} & Baseline & \textbf{312.5} & 136 & 55.4 & \textbf{0.67} & \textbf{0.04} \\
#  & \textbf{A-LLM (Ours)} & 212.5 & \textbf{46} & \textbf{20.7} & 1.00 & 0.60 \\
#  & \textit{Diff.} & \textit{-32.0\%} & \textit{\textbf{-65.9\%}} & \textit{\textbf{-62.6\%}} & \textit{+0.33} & +0.56 \\
# \midrule
# \multirow{3}{*}{Cell 3} & Baseline & \textbf{312.1} & 131 & 54.6 & \textbf{0.60} & \textbf{0.05} \\
#  & \textbf{A-LLM (Ours)} & 224.5 & \textbf{63} & \textbf{23.6} & 0.93 & 0.56 \\
#  & \textit{Diff.} & \textit{-28.1\%} & \textit{\textbf{-51.7\%}} & \textit{\textbf{-56.7\%}} & \textit{+0.33} & +0.51 \\
# \midrule
# \multirow{3}{*}{\textbf{Network Avg}} & Baseline & \textbf{307.1} & 132 & 54.7 & \textbf{0.67} & \textbf{0.05} \\
#  & \textbf{A-LLM (Ours)} & 212.0 & \textbf{48} & \textbf{20.7} & 0.96 & 0.61 \\
#  & \textit{Diff.} & \textit{-31.0\%} & \textit{\textbf{-63.5\%}} & \textit{\textbf{-62.1\%}} & \textit{+0.29} & +0.56 \\
# \toprule
# \multicolumn{7}{l}{\textbf{Localized DDoS Attack in Cell 3 (Step 40-50)}} \\
# \midrule
# \multirow{3}{*}{Cell 1} & Baseline & \textbf{391.3} & 60 & 60.0 & \textbf{0.00} & \textbf{0.00} \\
#  & \textbf{A-LLM (Ours)} & 170.6 & \textbf{5} & \textbf{5.0} & 1.00 & 1.00 \\
#  & \textit{Diff.} & \textit{-56.4\%} & \textit{\textbf{-91.7\%}} & \textit{\textbf{-91.7\%}} & \textit{+1.00} & +1.00 \\
# \midrule
# \multirow{3}{*}{Cell 2} & Baseline & \textbf{394.4} & 60 & 60.0 & \textbf{0.00} & \textbf{0.00} \\
#  & \textbf{A-LLM (Ours)} & 171.9 & \textbf{5} & \textbf{5.0} & 1.00 & 1.00 \\
#  & \textit{Diff.} & \textit{-56.4\%} & \textit{\textbf{-91.7\%}} & \textit{\textbf{-91.7\%}} & \textit{+1.00} & +1.00 \\
# \midrule
# \multirow{3}{*}{Cell 3 \textit{(Attacked)}} & Baseline & \textbf{593.1} & 60 & 60.0 & \textbf{0.00} & \textbf{0.00} \\
#  & \textbf{A-LLM (Ours)} & 258.5 & \textbf{5} & \textbf{5.0} & 1.00 & 1.00 \\
#  & \textit{Diff.} & \textit{-56.4\%} & \textit{\textbf{-91.7\%}} & \textit{\textbf{-91.7\%}} & \textit{+1.00} & +1.00 \\
# \midrule
# \multirow{3}{*}{\textbf{Network Avg}} & Baseline & \textbf{459.6} & 60 & 60.0 & \textbf{0.00} & \textbf{0.00} \\
#  & \textbf{A-LLM (Ours)} & 200.3 & \textbf{5} & \textbf{5.0} & 1.00 & 1.00 \\
#  & \textit{Diff.} & \textit{-56.4\%} & \textit{\textbf{-91.7\%}} & \textit{\textbf{-91.7\%}} & \textit{+1.00} & +1.00 \\
# \bottomrule
# \end{tabular}%
# }
# \vspace{0.1cm}
# \\ \footnotesize{\textit{Note: Diff. row shows percentage change for Thr/Cost/Power, and absolute difference ($\Delta$) for SLA/Risk. Bold indicates the superior metric.}}
# \end{table*}
